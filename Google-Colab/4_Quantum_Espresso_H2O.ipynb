# %% [markdown]
# <a href="https://colab.research.google.com/github/MosaicGroupCMU/African-MRS-Tutorials/blob/main/Google-Colab/4_Quantum_Espresso_H2O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to geometry optimization of molecular water using Quantum ESPRESSO
#
# Contributors: [Seda Oturak](https://github.com/sedaoturak), [Ismaila Dabo](https://scholar.google.com/citations?user=rN299m0AAAAJ&hl=en), [Jessica Wen](https://github.com/JessicaWen-PhD), [Cierra Chandler](https://github.com/Cierra-Chandler), [Henry Eya](https://github.com/Henrynweya)

# %% [markdown]
# # Step 1: Install libraries, environment, and Quantum ESPRESSO

# %% [markdown]
# This part installs libraries for numerical calculations and plotting.

# %%
# load plotting libraries
import matplotlib.pyplot as plt

# load numerical libraries
import numpy as np

# %% [markdown]
# Quantum ESPRESSO is a plane wave code, which uses Fourier transforms to solve equations in plane wave space. This part installs libraries for fast Fourier transforms (FFTs).

# %%
# eliminate text output during installation
# %%capture

# install mathematical libraries to peform fast Fourier transforms
# (the exclamation mark means that the command is run under Linux)
! apt-get install -y libfftw3-3 libfftw3-dev libfftw3-doc

# %% [markdown]
# The Atomic Simulation Environment (ASE) is a set of tools for running, visualizing, and analyzing simulations. This part installs ASE.

# %%
# eliminate text output during installation
# %%capture

# install the Atomic simulation environment
# ! apt install ase
! pip install git+https://gitlab.com/ase/ase

# %% [markdown]
# Compiling Quantum ESPRESSO from scratch would take a long time. This part uploads pre-compiled executable files (`.x` extension) and additional files containing the pseudopotentials.

# %%
# eliminate text output during installation
# %%capture

# navigate to main directory named '/content/'
# %cd /content/

# download the pre-compiled files in compressed format (under Linux)
#! wget 'https://docs.google.com/uc?export=download&id=1kw_CJMjP6ggDZXDNp5phAqCPpoe2WXCA' -O qe-lite.tgz
# !gdown 'https://drive.google.com/uc?export=download&id=13l-Kiyg-F6aYb5lF8M3RsE1hSnLRdGna' -O qe-lite.tgz

# unpack the compressed files (under Linux)
! tar -xvzf qe-lite.tgz

# clean up some files
! rm -rf sample_data qe-lite.tgz

# %% [markdown]
# # Step 2: Prepare Quantum ESPRESSO input file for SCF

# %% [markdown]
# The calculation is for a water molecule. The definition of the input parameters of the `pw.x` executable can be found at `www.quantum-espresso.org/Doc/INPUT_PW.html`.
#
# Things to note for molecules:
# 1. The molecule should be put in a vacuum
# 2. KPOINTS of 1 1 1 is used

# %%
# create calculation folder and navigate into it
# %mkdir -p /content/water
# %cd /content/water/

# create input and write it into the file h20.scf.in
qe_input = """
&control
  calculation='relax',
  prefix='h2o',
  pseudo_dir = '//content/qe-lite/pseudopotentials',
  outdir='/content/water'
  etot_conv_thr = 1e-5
  forc_conv_thr = 1e-4
/
&system
  ibrav = 0,
  nat = 3,
  ntyp = 2,
  ecutwfc = 30.0,
  ecutrho = 240.0,
  occupations  = 'smearing'
  degauss      = 0.001
  smearing     = 'marzari-vanderbilt'
/
&electrons
  conv_thr = 1e-8,

/
&ions
  ion_dynamics = 'bfgs'
/
ATOMIC_SPECIES
O 15.999 O.upf
H 1.008 H.upf

K_POINTS automatic
1 1 1 0 0 0

CELL_PARAMETERS angstrom
10.00000000000000 0.00000000000000 0.00000000000000
0.00000000000000 10.00000000000000 0.00000000000000
0.00000000000000 0.00000000000000 10.00000000000000

ATOMIC_POSITIONS angstrom
O 5.0000000000 5.0000000000 5.2981545000
H 5.0000000000 5.7632390000 4.7021545000
H 5.0000000000 4.2372390000 4.7021545000

"""

with open("h2o.relax.in", "w") as f:
    f.write(qe_input)

# print the content of the input file (under Linux)
! cat h2o.relax.in
# Out:
# /content/water
#
# &control
#   calculation='relax',
#   prefix='h2o',
#   pseudo_dir = '//content/qe-lite/pseudopotentials',
#   outdir='/content/water'
#   etot_conv_thr = 1e-5
#   forc_conv_thr = 1e-4
# /
# &system
#   ibrav = 0,
#   nat = 3,
#   ntyp = 2,
#   ecutwfc = 30.0,
#   ecutrho = 240.0,
#   occupations  = 'smearing'
#   degauss      = 0.001
#   smearing     = 'marzari-vanderbilt'
# /
# &electrons
#   conv_thr = 1e-8,
#
# /
# &ions
#   ion_dynamics = 'bfgs'
# /
# ATOMIC_SPECIES
# O 15.999 O.upf
# H 1.008 H.upf
#
# K_POINTS automatic
# 1 1 1 0 0 0
#
# CELL_PARAMETERS angstrom
# 10.00000000000000 0.00000000000000 0.00000000000000
# 0.00000000000000 10.00000000000000 0.00000000000000
# 0.00000000000000 0.00000000000000 10.00000000000000
#
# ATOMIC_POSITIONS angstrom
# O 5.0000000000 5.0000000000 5.2981545000
# H 5.0000000000 5.7632390000 4.7021545000
# H 5.0000000000 4.2372390000 4.7021545000

# %% [markdown]
# Use ASE tools to extract information from Quantum ESPRESSO input and visualize the crystal.

# %%
import ase.io.espresso
from ase import Atoms
from ase.visualize import view
from ase.build import make_supercell
from ase.build import bulk

# extract unit cell information from input file using ASE
input_file = ase.io.espresso.read_espresso_in('h2o.relax.in')
water = Atoms(input_file)

# create a supercell (2 × 2 × 2) using ASE
#multiplier = np.identity(3) * 2
#water_supercell = make_supercell(water,multiplier)

"""
#For non-square array (for example 1 x 2 x 1), you can use the follwoing lines

multiplier = np.array([
    [3, 0, 0],  # x-dimension unchanged
    [0, 2, 0],  # y-dimension scaled by 2
    [0, 0, 2]   # z-dimension unchanged
])
water_supercell = make_supercell(water,multiplier)
"""
#visualize unit cell
view(water, viewer='x3d')


# visualize the supercell
#view(water_supercell, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 20.0">
#     <group/>
#   </viewpoint>
#   <transform translation="-5.0 -5.0 -5.0">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.0 0.0 0.0 10.0 10.0 0.0 0.0 10.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.0 0.0 0.0 10.0 10.0 0.0 0.0 10.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.0 0.0 0.0 10.0 0.0 10.0 0.0 0.0 10.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 10.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.0 0.0 0.0 10.0 0.0 10.0 0.0 0.0 10.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="5.0 5.0 5.2981545">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="5.0 5.763239 4.7021545">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="5.0 4.237239 4.7021545">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %% [markdown]
# # Step 3: Run Quantum ESPRESSO using input file

# %%
# run the pw.x executable using si.scf.in to create si.scf.out
! /content/qe-lite/bin/pw.x < h2o.relax.in > h2o.relax.out

# print the content of the output file (under Linux)
! cat h2o.relax.out
# Out:
#      Program PWSCF v.7.4 starts on 15Dec2024 at  5: 2:30
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#          "P. Giannozzi et al., J. Chem. Phys. 152 154105 (2020);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Serial version
#      9244 MiB available memory on the printing compute node when the environment starts
#
#      Waiting for input...
#      Reading input from standard input
#
#      Current dimensions of program PWSCF are:
#      Max number of different atomic species (ntypx) = 10
#      Max number of k-points (npk) =  40000
#      Max angular momentum in pseudopotentials (lmaxx) =  4
#      file O.upf: wavefunction(s)  2P renormalized
#      Message from routine setup:
#      using ibrav=0 with symmetry is DISCOURAGED, use correct ibrav instead
#
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum        6817    3397    853               423701   149781   18805
#
#      Using Slab Decomposition
#
#
#
#      bravais-lattice index     =            0
#      lattice parameter (alat)  =      18.8973  a.u.
#      unit-cell volume          =    6748.3345 (a.u.)^3
#      number of atoms/cell      =            3
#      number of atomic types    =            2
#      number of electrons       =         8.00
#      number of Kohn-Sham states=            8
#      kinetic-energy cutoff     =      30.0000  Ry
#      charge density cutoff     =     240.0000  Ry
#      scf convergence threshold =      1.0E-08
#      mixing beta               =       0.7000
#      number of iterations used =            8  plain     mixing
#      energy convergence thresh.=      1.0E-05
#      force convergence thresh. =      1.0E-04
#      Exchange-correlation= PBE
#                            (   1   4   3   4   0   0   0)
#      nstep                     =           50
#
#
#      celldm(1)=  18.897261  celldm(2)=   0.000000  celldm(3)=   0.000000
#      celldm(4)=   0.000000  celldm(5)=   0.000000  celldm(6)=   0.000000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (   1.000000   0.000000   0.000000 )
#                a(2) = (   0.000000   1.000000   0.000000 )
#                a(3) = (   0.000000   0.000000   1.000000 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  1.000000  0.000000  0.000000 )
#                b(2) = (  0.000000  1.000000  0.000000 )
#                b(3) = (  0.000000  0.000000  1.000000 )
#
#
#      PseudoPot. # 1 for O  read from file:
#      //content/qe-lite/pseudopotentials/O.upf
#      MD5 check sum: 0234752ac141de4415c5fc33072bef88
#      Pseudo is Projector augmented-wave + core cor, Zval =  6.0
#      Generated using "atomic" code by A. Dal Corso  v.5.0.99 svn rev. 10869
#      Shape of augmentation charge: BESSEL
#      Using radial grid of 1095 points,  4 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#                 l(4) =   1
#      Q(r) pseudized with 0 coefficients
#
#
#      PseudoPot. # 2 for H  read from file:
#      //content/qe-lite/pseudopotentials/H.upf
#      MD5 check sum: f52b6d4d1c606e5624b1dc7b2218f220
#      Pseudo is Ultrasoft, Zval =  1.0
#      Generated using "atomic" code by A. Dal Corso  v.5.1
#      Using radial grid of  929 points,  2 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#      Q(r) pseudized with 0 coefficients
#
#
#      atomic species   valence    mass     pseudopotential
#      O                 6.00    15.99900     O ( 1.00)
#      H                 1.00     1.00800     H ( 1.00)
#
#       2 Sym. Ops. (no inversion) found
#
#
#
#    Cartesian axes
#
#      site n.     atom                  positions (alat units)
#          1        O      tau(   1) = (   0.5000000   0.5000000   0.5298155  )
#          2        H      tau(   2) = (   0.5000000   0.5763239   0.4702155  )
#          3        H      tau(   3) = (   0.5000000   0.4237239   0.4702155  )
#
#      number of k points=     1  Marzari-Vanderbilt smearing, width (Ry)=  0.0010
#                        cart. coord. in units 2pi/alat
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   2.0000000
#
#      Dense  grid:   423701 G-vectors     FFT dimensions: (  96,  96,  96)
#
#      Smooth grid:   149781 G-vectors     FFT dimensions: (  72,  72,  72)
#
#      Estimated max dynamical RAM per process >     561.29 MB
#
#      Check: negative core charge=   -0.000001
#
#      Initial potential from superposition of free atoms
#
#      starting charge       8.0000, renormalised to       8.0000
#
#      negative rho (up, down):  2.358E-03 0.000E+00
#      Starting wfcs are    6 randomized atomic wfcs +    2 random wfcs
#
#      total cpu time spent up to now is        4.3 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-02,  avg # of iterations =  8.0
#
#      negative rho (up, down):  3.466E-03 0.000E+00
#
#      total cpu time spent up to now is        7.0 secs
#
#      total energy              =     -43.80316292 Ry
#      estimated scf accuracy    <       0.40875244 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  5.11E-03,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.937E-03 0.000E+00
#
#      total cpu time spent up to now is        9.7 secs
#
#      total energy              =     -43.89667189 Ry
#      estimated scf accuracy    <       0.36807765 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  4.60E-03,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.834E-03 0.000E+00
#
#      total cpu time spent up to now is       11.7 secs
#
#      total energy              =     -43.96991880 Ry
#      estimated scf accuracy    <       0.00415421 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  5.19E-05,  avg # of iterations =  6.0
#
#      negative rho (up, down):  2.884E-03 0.000E+00
#
#      total cpu time spent up to now is       13.9 secs
#
#      total energy              =     -43.97067208 Ry
#      estimated scf accuracy    <       0.00076579 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  9.57E-06,  avg # of iterations = 14.0
#
#      negative rho (up, down):  2.913E-03 0.000E+00
#
#      total cpu time spent up to now is       16.0 secs
#
#      total energy              =     -43.97063704 Ry
#      estimated scf accuracy    <       0.00012774 Ry
#
#      iteration #  6     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.60E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.917E-03 0.000E+00
#
#      total cpu time spent up to now is       18.0 secs
#
#      total energy              =     -43.97066409 Ry
#      estimated scf accuracy    <       0.00000196 Ry
#
#      iteration #  7     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.46E-08,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.921E-03 0.000E+00
#
#      total cpu time spent up to now is       20.3 secs
#
#      total energy              =     -43.97066414 Ry
#      estimated scf accuracy    <       0.00000061 Ry
#
#      iteration #  8     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  7.67E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  2.921E-03 0.000E+00
#
#      total cpu time spent up to now is       22.9 secs
#
#      total energy              =     -43.97066408 Ry
#      estimated scf accuracy    <       0.00000018 Ry
#
#      iteration #  9     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.28E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.922E-03 0.000E+00
#
#      total cpu time spent up to now is       24.8 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.3405 -12.9746  -9.2311  -7.1090  -0.9858   0.3470   0.7215   1.0348
#
#      the Fermi energy is    -5.4910 ev
#
# !    total energy              =     -43.97066410 Ry
#      estimated scf accuracy    <          2.4E-09 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97066410 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.88571183 Ry
#      hartree contribution      =      33.02269840 Ry
#      xc contribution           =      -8.82343003 Ry
#      ewald contribution        =       4.23215840 Ry
#      one-center paw contrib.   =      -9.51637905 Ry
#
#      convergence has been achieved in   9 iterations
#
#      negative rho (up, down):  2.922E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00058140    0.02273231
#      atom    2 type  2   force =     0.00000000    0.01488700   -0.01113565
#      atom    3 type  2   force =     0.00000000   -0.01546840   -0.01159666
#
#      Total force =     0.035164     Total SCF correction =     0.000148
#
#      BFGS Geometry Optimization
#      Energy error            =      1.2E-03 Ry
#      Gradient error          =      2.3E-02 Ry/Bohr
#
#      number of scf cycles    =   1
#      number of bfgs steps    =   0
#
#      energy             new  =     -43.9706641034 Ry
#
#      new trust radius        =       0.0227397426 bohr
#      new conv_thr            =       0.0000000100 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0003076634        5.3101839198
# H                5.0000000000        5.7711168610        4.6962617675
# H                5.0000000000        4.2290534756        4.6960178127
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000001
#
#      negative rho (up, down):  2.898E-03 0.000E+00
#
#      total cpu time spent up to now is       27.4 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  4.0
#
#      negative rho (up, down):  2.849E-03 0.000E+00
#
#      total cpu time spent up to now is       29.6 secs
#
#      total energy              =     -43.97060830 Ry
#      estimated scf accuracy    <       0.00062457 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  7.81E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       31.6 secs
#
#      total energy              =     -43.97074928 Ry
#      estimated scf accuracy    <       0.00052608 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.58E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.884E-03 0.000E+00
#
#      total cpu time spent up to now is       33.9 secs
#
#      total energy              =     -43.97085856 Ry
#      estimated scf accuracy    <       0.00000232 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.90E-08,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.879E-03 0.000E+00
#
#      total cpu time spent up to now is       36.5 secs
#
#      total energy              =     -43.97085900 Ry
#      estimated scf accuracy    <       0.00000074 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  9.28E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.878E-03 0.000E+00
#
#      total cpu time spent up to now is       38.4 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.1678 -12.7654  -9.2597  -7.0763  -1.0314   0.3204   0.6894   1.0292
#
#      the Fermi energy is    -5.4520 ev
#
# !    total energy              =     -43.97085913 Ry
#      estimated scf accuracy    <          6.2E-09 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97085913 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.48795507 Ry
#      hartree contribution      =      32.83417743 Ry
#      xc contribution           =      -8.79188725 Ry
#      ewald contribution        =       3.99331021 Ry
#      one-center paw contrib.   =      -9.51850445 Ry
#
#      convergence has been achieved in   5 iterations
#
#      negative rho (up, down):  2.878E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000   -0.00069374   -0.01651291
#      atom    2 type  2   force =     0.00000000   -0.00794213    0.00798130
#      atom    3 type  2   force =     0.00000000    0.00863587    0.00853161
#
#      Total force =     0.023394     Total SCF correction =     0.000133
#      Energy error            =      2.0E-04 Ry
#      Gradient error          =      1.7E-02 Ry/Bohr
#
#      number of scf cycles    =   2
#      number of bfgs steps    =   1
#
#      energy             old  =     -43.9706641034 Ry
#      energy             new  =     -43.9708591291 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0098956401 bohr
#      new conv_thr            =       0.0000000020 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0000873066        5.3049520110
# H                5.0000000000        5.7686063732        4.6987903209
# H                5.0000000000        4.2317843202        4.6987211681
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000001
#
#      negative rho (up, down):  2.888E-03 0.000E+00
#
#      total cpu time spent up to now is       40.9 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  3.0
#
#      negative rho (up, down):  2.907E-03 0.000E+00
#
#      total cpu time spent up to now is       43.1 secs
#
#      total energy              =     -43.97098754 Ry
#      estimated scf accuracy    <       0.00010051 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.26E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.888E-03 0.000E+00
#
#      total cpu time spent up to now is       45.1 secs
#
#      total energy              =     -43.97101179 Ry
#      estimated scf accuracy    <       0.00008514 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.06E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.893E-03 0.000E+00
#
#      total cpu time spent up to now is       47.4 secs
#
#      total energy              =     -43.97102882 Ry
#      estimated scf accuracy    <       0.00000029 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  3.59E-09,  avg # of iterations =  3.0
#
#      negative rho (up, down):  2.895E-03 0.000E+00
#
#      total cpu time spent up to now is       50.0 secs
#
#      total energy              =     -43.97102890 Ry
#      estimated scf accuracy    <       0.00000015 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.84E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.895E-03 0.000E+00
#
#      total cpu time spent up to now is       51.9 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.2333 -12.8520  -9.2427  -7.0881  -1.0126   0.3311   0.7026   1.0310
#
#      the Fermi energy is    -5.4670 ev
#
# !    total energy              =     -43.97102893 Ry
#      estimated scf accuracy    <          1.5E-09 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97102893 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.64375074 Ry
#      hartree contribution      =      32.90809656 Ry
#      xc contribution           =      -8.80421068 Ry
#      ewald contribution        =       4.08646786 Ry
#      one-center paw contrib.   =      -9.51763193 Ry
#
#      convergence has been achieved in   5 iterations
#
#      negative rho (up, down):  2.895E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00018450   -0.00098784
#      atom    2 type  2   force =     0.00000000    0.00028492    0.00056651
#      atom    3 type  2   force =     0.00000000   -0.00046942    0.00042133
#
#      Total force =     0.001345     Total SCF correction =     0.000086
#      Energy error            =      1.7E-04 Ry
#      Gradient error          =      9.9E-04 Ry/Bohr
#
#      number of scf cycles    =   3
#      number of bfgs steps    =   2
#
#      energy             old  =     -43.9708591291 Ry
#      energy             new  =     -43.9710289289 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0008622761 bohr
#      new conv_thr            =       0.0000000010 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0001919742        5.3045078809
# H                5.0000000000        5.7688121885        4.6990535772
# H                5.0000000000        4.2314738373        4.6989020418
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000001
#
#      negative rho (up, down):  2.895E-03 0.000E+00
#
#      total cpu time spent up to now is       54.5 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  2.0
#
#      Threshold (ethr) on eigenvalues was too large:
#      Diagonalizing with lowered threshold
#
#      Davidson diagonalization with overlap
#      ethr =  2.61E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.896E-03 0.000E+00
#
#      total cpu time spent up to now is       57.5 secs
#
#      total energy              =     -43.97103010 Ry
#      estimated scf accuracy    <       0.00000020 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.48E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.896E-03 0.000E+00
#
#      total cpu time spent up to now is       59.5 secs
#
#      total energy              =     -43.97103013 Ry
#      estimated scf accuracy    <       0.00000012 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.53E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.896E-03 0.000E+00
#
#      total cpu time spent up to now is       62.2 secs
#
#      total energy              =     -43.97103016 Ry
#      estimated scf accuracy    <          3.2E-09 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  3.98E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.896E-03 0.000E+00
#
#      total cpu time spent up to now is       64.4 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.2343 -12.8579  -9.2392  -7.0884  -1.0119   0.3315   0.7028   1.0309
#
#      the Fermi energy is    -5.4674 ev
#
# !    total energy              =     -43.97103016 Ry
#      estimated scf accuracy    <          3.1E-10 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97103016 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.64830137 Ry
#      hartree contribution      =      32.91044659 Ry
#      xc contribution           =      -8.80460648 Ry
#      ewald contribution        =       4.08901075 Ry
#      one-center paw contrib.   =      -9.51757965 Ry
#
#      convergence has been achieved in   4 iterations
#
#      negative rho (up, down):  2.896E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000   -0.00025136   -0.00032464
#      atom    2 type  2   force =     0.00000000    0.00059678    0.00006480
#      atom    3 type  2   force =     0.00000000   -0.00034542    0.00025983
#
#      Total force =     0.000846     Total SCF correction =     0.000023
#      Energy error            =      1.2E-06 Ry
#      Gradient error          =      6.0E-04 Ry/Bohr
#
#      number of scf cycles    =   4
#      number of bfgs steps    =   3
#
#      energy             old  =     -43.9710289289 Ry
#      energy             new  =     -43.9710301596 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0014877167 bohr
#      new conv_thr            =            1.0E-10 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0000210256        5.3038353546
# H                5.0000000000        5.7695515708        4.6993239493
# H                5.0000000000        4.2309054036        4.6993041961
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000001
#
#      negative rho (up, down):  2.895E-03 0.000E+00
#
#      total cpu time spent up to now is       66.9 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  2.0
#
#      Threshold (ethr) on eigenvalues was too large:
#      Diagonalizing with lowered threshold
#
#      Davidson diagonalization with overlap
#      ethr =  3.17E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       69.9 secs
#
#      total energy              =     -43.97103095 Ry
#      estimated scf accuracy    <       0.00000026 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  3.20E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       71.8 secs
#
#      total energy              =     -43.97103097 Ry
#      estimated scf accuracy    <       0.00000004 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  5.53E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       74.1 secs
#
#      total energy              =     -43.97103098 Ry
#      estimated scf accuracy    <       0.00000002 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.49E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       76.8 secs
#
#      total energy              =     -43.97103098 Ry
#      estimated scf accuracy    <          1.5E-10 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.93E-12,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       78.7 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.2329 -12.8655  -9.2323  -7.0879  -1.0114   0.3320   0.7027   1.0307
#
#      the Fermi energy is    -5.4672 ev
#
# !    total energy              =     -43.97103098 Ry
#      estimated scf accuracy    <          1.5E-11 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97103098 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.65000995 Ry
#      hartree contribution      =      32.91136097 Ry
#      xc contribution           =      -8.80475305 Ry
#      ewald contribution        =       4.08988734 Ry
#      one-center paw contrib.   =      -9.51751629 Ry
#
#      convergence has been achieved in   5 iterations
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00045628    0.00035577
#      atom    2 type  2   force =     0.00000000    0.00003518    0.00000166
#      atom    3 type  2   force =     0.00000000   -0.00049146   -0.00035743
#
#      Total force =     0.000840     Total SCF correction =     0.000007
#      Energy error            =      8.2E-07 Ry
#      Gradient error          =      4.9E-04 Ry/Bohr
#
#      number of scf cycles    =   5
#      number of bfgs steps    =   4
#
#      energy             old  =     -43.9710301596 Ry
#      energy             new  =     -43.9710309815 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0004835786 bohr
#      new conv_thr            =            1.0E-10 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0001789277        5.3038570068
# H                5.0000000000        5.7696388712        4.6993755090
# H                5.0000000000        4.2306602012        4.6992309842
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000001
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       81.2 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  2.0
#
#      Threshold (ethr) on eigenvalues was too large:
#      Diagonalizing with lowered threshold
#
#      Davidson diagonalization with overlap
#      ethr =  7.24E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       84.2 secs
#
#      total energy              =     -43.97103113 Ry
#      estimated scf accuracy    <       0.00000007 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  9.15E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       86.1 secs
#
#      total energy              =     -43.97103114 Ry
#      estimated scf accuracy    <       0.00000003 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  4.25E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       88.7 secs
#
#      total energy              =     -43.97103114 Ry
#      estimated scf accuracy    <          1.8E-09 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.27E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       91.0 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.2311 -12.8646  -9.2316  -7.0875  -1.0118   0.3318   0.7024   1.0305
#
#      the Fermi energy is    -5.4669 ev
#
# !    total energy              =     -43.97103115 Ry
#      estimated scf accuracy    <          4.6E-11 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97103115 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.64648322 Ry
#      hartree contribution      =      32.90970737 Ry
#      xc contribution           =      -8.80447612 Ry
#      ewald contribution        =       4.08774863 Ry
#      one-center paw contrib.   =      -9.51752780 Ry
#
#      convergence has been achieved in   4 iterations
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000   -0.00019945    0.00007889
#      atom    2 type  2   force =     0.00000000    0.00011440   -0.00011701
#      atom    3 type  2   force =     0.00000000    0.00008505    0.00003812
#
#      Total force =     0.000285     Total SCF correction =     0.000010
#      Energy error            =      1.7E-07 Ry
#      Gradient error          =      2.0E-04 Ry/Bohr
#
#      number of scf cycles    =   6
#      number of bfgs steps    =   5
#
#      energy             old  =     -43.9710309815 Ry
#      energy             new  =     -43.9710311471 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0001295495 bohr
#      new conv_thr            =            1.0E-10 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0001332487        5.3039081261
# H                5.0000000000        5.7696281998        4.6993322274
# H                5.0000000000        4.2307165515        4.6992231465
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000001
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       93.6 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  2.0
#
#      Threshold (ethr) on eigenvalues was too large:
#      Diagonalizing with lowered threshold
#
#      Davidson diagonalization with overlap
#      ethr =  4.30E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       96.5 secs
#
#      total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          4.2E-09 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  5.31E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is       98.4 secs
#
#      total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          6.4E-10 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  8.04E-12,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is      100.6 secs
#
#      total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          2.2E-10 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  2.71E-12,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      total cpu time spent up to now is      103.3 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 ( 18805 PWs)   bands (ev):
#
#    -25.2310 -12.8640  -9.2321  -7.0875  -1.0118   0.3317   0.7024   1.0304
#
#      the Fermi energy is    -5.4670 ev
#
# !    total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          3.1E-12 Ry
#      smearing contrib. (-TS)   =       0.00000000 Ry
#      internal energy E=F+TS    =     -43.97103118 Ry
#
#      The total energy is F=E-TS. E is the sum of the following terms:
#      one-electron contribution =     -62.64606778 Ry
#      hartree contribution      =      32.90951405 Ry
#      xc contribution           =      -8.80444432 Ry
#      ewald contribution        =       4.08750024 Ry
#      one-center paw contrib.   =      -9.51753337 Ry
#
#      convergence has been achieved in   4 iterations
#
#      negative rho (up, down):  2.897E-03 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000   -0.00000842    0.00000571
#      atom    2 type  2   force =     0.00000000    0.00001212   -0.00000619
#      atom    3 type  2   force =     0.00000000   -0.00000370    0.00000048
#
#      Total force =     0.000017     Total SCF correction =     0.000002
#      SCF correction compared to forces is large: reduce conv_thr to get better values
#      Energy error            =      3.0E-08 Ry
#      Gradient error          =      1.2E-05 Ry/Bohr
#
#      bfgs converged in   7 scf cycles and   6 bfgs steps
#      (criteria: energy <  1.0E-05 Ry, force <  1.0E-04 Ry/Bohr)
#
#      End of BFGS Geometry Optimization
#
#      Final energy             =     -43.9710311770 Ry
#
#      File /content/water/h2o.bfgs deleted, as requested
# Begin final coordinates
#
# ATOMIC_POSITIONS (angstrom)
# O                5.0000000000        5.0001332487        5.3039081261
# H                5.0000000000        5.7696281998        4.6993322274
# H                5.0000000000        4.2307165515        4.6992231465
# End final coordinates
#
#
#
#      Writing all to output data dir /content/water/h2o.save/ :
#      XML data file, charge density, pseudopotentials, collected wavefunctions
#
#      init_run     :      3.39s CPU      4.20s WALL (       1 calls)
#      electrons    :     68.06s CPU     83.92s WALL (       7 calls)
#      update_pot   :      3.07s CPU      3.43s WALL (       6 calls)
#      forces       :      7.56s CPU      9.22s WALL (       7 calls)
#
#      Called by init_run:
#      wfcinit      :      0.58s CPU      0.59s WALL (       1 calls)
#      potinit      :      1.03s CPU      1.31s WALL (       1 calls)
#      hinit0       :      1.17s CPU      1.28s WALL (       1 calls)
#
#      Called by electrons:
#      c_bands      :     10.73s CPU     10.90s WALL (      40 calls)
#      sum_band     :     22.39s CPU     29.75s WALL (      40 calls)
#      v_of_rho     :     17.34s CPU     19.84s WALL (      43 calls)
#      newd         :     16.96s CPU     24.39s WALL (      43 calls)
#      PAW_pot      :      2.58s CPU      2.61s WALL (      49 calls)
#      mix_rho      :      1.97s CPU      2.09s WALL (      40 calls)
#
#      Called by c_bands:
#      init_us_2    :      0.45s CPU      0.46s WALL (      94 calls)
#      cegterg      :     10.39s CPU     10.56s WALL (      40 calls)
#
#      Called by *egterg:
#      cdiaghg      :      0.02s CPU      0.02s WALL (     135 calls)
#      h_psi        :      9.97s CPU     10.09s WALL (     146 calls)
#      s_psi        :      0.12s CPU      0.12s WALL (     146 calls)
#      g_psi        :      0.05s CPU      0.05s WALL (     105 calls)
#
#      Called by h_psi:
#      h_psi:calbec :      0.14s CPU      0.14s WALL (     146 calls)
#      vloc_psi     :      9.64s CPU      9.75s WALL (     146 calls)
#      add_vuspsi   :      0.14s CPU      0.14s WALL (     146 calls)
#
#      General routines
#      calbec       :      0.23s CPU      0.23s WALL (     220 calls)
#      fft          :     10.91s CPU     11.05s WALL (     632 calls)
#      ffts         :      0.99s CPU      1.00s WALL (      83 calls)
#      fftw         :      8.15s CPU      8.25s WALL (    2004 calls)
#      interpolate  :      1.78s CPU      1.80s WALL (      43 calls)
#
#
#      PWSCF        :   1m25.04s CPU   1m44.78s WALL
#
#
#    This run was terminated on:   5: 4:14  15Dec2024
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=

# %% [markdown]
# #Step 4: Extract the total energy of the system

# %%
# First method: xtract total energies in rydberg during the self-consistent-field calculation (under Linux)
! grep -e "total energy  " -e "estimated" h2o.relax.out #NOTE: grep is a power comand that can seacrh and list the specified term in a file
# Out:
#      total energy              =     -43.80316292 Ry
#      estimated scf accuracy    <       0.40875244 Ry
#      total energy              =     -43.89667189 Ry
#      estimated scf accuracy    <       0.36807765 Ry
#      total energy              =     -43.96991880 Ry
#      estimated scf accuracy    <       0.00415421 Ry
#      total energy              =     -43.97067208 Ry
#      estimated scf accuracy    <       0.00076579 Ry
#      total energy              =     -43.97063704 Ry
#      estimated scf accuracy    <       0.00012774 Ry
#      total energy              =     -43.97066409 Ry
#      estimated scf accuracy    <       0.00000196 Ry
#      total energy              =     -43.97066414 Ry
#      estimated scf accuracy    <       0.00000061 Ry
#      total energy              =     -43.97066408 Ry
#      estimated scf accuracy    <       0.00000018 Ry
# !    total energy              =     -43.97066410 Ry
#      estimated scf accuracy    <          2.4E-09 Ry
#      total energy              =     -43.97060830 Ry
#      estimated scf accuracy    <       0.00062457 Ry
#      total energy              =     -43.97074928 Ry
#      estimated scf accuracy    <       0.00052608 Ry
#      total energy              =     -43.97085856 Ry
#      estimated scf accuracy    <       0.00000232 Ry
#      total energy              =     -43.97085900 Ry
#      estimated scf accuracy    <       0.00000074 Ry
# !    total energy              =     -43.97085913 Ry
#      estimated scf accuracy    <          6.2E-09 Ry
#      total energy              =     -43.97098754 Ry
#      estimated scf accuracy    <       0.00010051 Ry
#      total energy              =     -43.97101179 Ry
#      estimated scf accuracy    <       0.00008514 Ry
#      total energy              =     -43.97102882 Ry
#      estimated scf accuracy    <       0.00000029 Ry
#      total energy              =     -43.97102890 Ry
#      estimated scf accuracy    <       0.00000015 Ry
# !    total energy              =     -43.97102893 Ry
#      estimated scf accuracy    <          1.5E-09 Ry
#      total energy              =     -43.97103010 Ry
#      estimated scf accuracy    <       0.00000020 Ry
#      total energy              =     -43.97103013 Ry
#      estimated scf accuracy    <       0.00000012 Ry
#      total energy              =     -43.97103016 Ry
#      estimated scf accuracy    <          3.2E-09 Ry
# !    total energy              =     -43.97103016 Ry
#      estimated scf accuracy    <          3.1E-10 Ry
#      total energy              =     -43.97103095 Ry
#      estimated scf accuracy    <       0.00000026 Ry
#      total energy              =     -43.97103097 Ry
#      estimated scf accuracy    <       0.00000004 Ry
#      total energy              =     -43.97103098 Ry
#      estimated scf accuracy    <       0.00000002 Ry
#      total energy              =     -43.97103098 Ry
#      estimated scf accuracy    <          1.5E-10 Ry
# !    total energy              =     -43.97103098 Ry
#      estimated scf accuracy    <          1.5E-11 Ry
#      total energy              =     -43.97103113 Ry
#      estimated scf accuracy    <       0.00000007 Ry
#      total energy              =     -43.97103114 Ry
#      estimated scf accuracy    <       0.00000003 Ry
#      total energy              =     -43.97103114 Ry
#      estimated scf accuracy    <          1.8E-09 Ry
# !    total energy              =     -43.97103115 Ry
#      estimated scf accuracy    <          4.6E-11 Ry
#      total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          4.2E-09 Ry
#      total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          6.4E-10 Ry
#      total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          2.2E-10 Ry
# !    total energy              =     -43.97103118 Ry
#      estimated scf accuracy    <          3.1E-12 Ry

# %%
# define physical constants for unit conversion
from scipy.constants import physical_constants
ha_in_ev = physical_constants["Hartree energy in eV"][0]
ry_in_ev = ha_in_ev / 2.

# second method: extract total energy at the end of the self-consistent calculation (using ASE)
output = ase.io.read("/content/water/h2o.relax.out")
total_energy = output.get_total_energy()
print("Energy = %.8f eV " % total_energy)
print("Energy = %.8f Ry " % ( total_energy / ry_in_ev ) )
# Out:
# Energy = -598.25630420 eV
# Energy = -43.97102733 Ry

# %%
# Input file for charge density plot
input_pp = """
&inputpp
     prefix='water',
     outdir='/content/water'
    filplot = 'water_charge_density'
     plot_num = 0,
/
  &plot
    nfile = 1
    filepp(1) = 'water_charge_density'
    weight(1) = 1.0
    iflag = 2
    output_format = 2
    fileout = 'water.rho.dat'
    e1(1) =1.0, e1(2)=0.0, e1(3) = 0.0,
    e2(1) =0.0, e2(2)=0.0, e2(3) = 1.0,
    nx=40, ny=40
/
"""

# Save the input file
with open("water_pp.in", "w") as file:
    file.write(input_pp)

# Run the post-processing calculation
! /content/qe-lite/bin/pp.x < water_pp.in > water_pp.out

#print("Charge density calculation completed. Check water_charge_density.cube for the output.")
# !cat water_pp.out

# %%
input_plotrho = """
water.rho.dat
water.rho.ps
n
min_rho -10
max_rho 20
n_levels 2
"""

# Save the input file
with open("water_plotrho.in", "w") as file:
    file.write(input_plotrho)

! /content/qe-lite/bin/plotrho.x water_plotrho.in

# %%
from PIL import Image

psimage=Image.open('water.rho.ps')
psimage.save('water.rho.png')
