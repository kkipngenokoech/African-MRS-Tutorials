# %% [markdown]
# <a href="https://colab.research.google.com/github/MosaicGroupCMU/African-MRS-Tutorials/blob/main/Google-Colab/Answers/6_QE_Vibrational_Modes_H2O_Answers_Full_Install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Quantum ESPRESSO and ASE
#
# **Run the cell below at the start of today's class to install QE and ASE.**
#
# Quantum ESPRESSO is a plane wave code, which uses Fourier transforms to solve equations in plane wave space. Here we install libraries for fast Fourier transforms (FFTs).
#
# The Atomic Simulation Environment (ASE) is a set of tools for running, visualizing, and analyzing simulations.

# %%
# eliminate text output during installation
# %%capture

# install mathematical libraries to peform fast Fourier transforms
# !apt-get install -y libfftw3-3 libfftw3-dev libfftw3-doc

# %%
# %%capture

# navigate to main directory named '/content/'
# %cd /content/

# download the pre-compiled files in compressed format (under Linux)
#! wget 'https://docs.google.com/uc?export=download&id=1kw_CJMjP6ggDZXDNp5phAqCPpoe2WXCA' -O qe-lite.tgz
# !gdown 'https://drive.google.com/uc?export=download&id=13l-Kiyg-F6aYb5lF8M3RsE1hSnLRdGna' -O qe-lite.tgz

# unpack the compressed files (under Linux)
! tar -xvzf qe-lite.tgz

# clean up some files
! rm -rf sample_data qe-lite.tgz

# %%
# %%capture

# install the Atomic simulation environment - may take ~3 mins
# ! apt install ase
! pip install git+https://gitlab.com/ase/ase

# %% [markdown]
# ---
# # Vibrational Modes of Molecules and Extended Systems
#
# Prerequisite: `5_QE_Vibrational_Modes_H2_Answers_Full_Install.ipynb`
#
# Contributors: [Lorenzo Bastonero](https://github.com/bastonero), [Jessica Wen](https://github.com/JessicaWen-PhD)
#
# This easy workbook is designed for people who are unfamiliar with Python and terminal commands.
#
# If this notebook is too easy for you, there is a [medium-level workbook]() designed for people who have done Python and worked with terminal commands before, but are unfamiliar with Quantum ESPRESSO; if you have already dabbled in some Quantum ESPRESSO, you can try the [hard version]() of the workbook.
#
# ## Learning Objectives
#
# In this tutorial, you will lean how to calculate infrared and Raman spectra from first-principles in the non-resonant regime and harmonic approximation by using the Quantum ESPRESSO distribution.
#
# Vibrational spectra, such as infrared (IR) and Raman, provide access to the collective atomic vibrations of materials. Each peak corresponds to a particular collective vibration, referred to as _normal mode_. These normal modes are characteristics of the each specific system, and can be used to characterize real samples (e.g., for quality control).
#
# So, the question now is: how can we compute the _frequency_ and _intensity_ of the vibrations?
#
# We have already found the method to compute the frequency of vibrations from `5_QE_Vibrational_Modes_H2_Answers_Full_Install.ipynb`.
#
# Now we can calculate the _intensity_ of the vibrations using water as an example.

# %% [markdown]
# # The harmonic approximation
#
# Remember, atoms in molecules and solids vibrate around their _equilibrium_ positions.
#
# ![n2harmonicoscillation.png](https://upload.wikimedia.org/wikipedia/commons/a/aa/N2ground.png)

# %% [markdown]
# # Setup
#
# This part installs libraries for numerical calculations and plotting.

# %%
import os
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# This part uploads the pseudopotentials needed for our calculations.

# %%
# eliminate text output during installation
# %%capture

# create pseudopotentials folder and navigate into it
# %mkdir -p /content/q-e/pseudopotentials
# %cd /content/q-e/pseudopotentials/

# download the H and O pseudopotential files from the GitHub
! wget https://raw.githubusercontent.com/MosaicGroupCMU/African-MRS-Tutorials/refs/heads/main/Google-Colab/H.UPF
! wget https://raw.githubusercontent.com/MosaicGroupCMU/African-MRS-Tutorials/refs/heads/main/Google-Colab/O.UPF

# navigate to main directory named '/content/'
# %cd ../../..

# clean up some files
! rm -rf content/sample_data

# %% [markdown]
# ## $H_2O$: infrared spectra

# %% [markdown]
# ### Step 1: define a structure
#
# Let's define the structure of water using ASE.

# %%
from ase import build
from ase.build import molecule
from ase.visualize import view
from ase.io import read, write

h2o = molecule('H2O', vacuum=3.0, pbc=True)

view(h2o, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 15.052956">
#     <group/>
#   </viewpoint>
#   <transform translation="-3.0 -3.763239 -3.2981545">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 7.526478 0.0 0.0 7.526478 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 6.596309">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 7.526478 0.0 0.0 7.526478 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 0.0 6.596309 0.0 0.0 6.596309 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 7.526478 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 0.0 6.596309 0.0 0.0 6.596309 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="3.0 3.7632390000000004 3.5963089999999998">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="3.0 4.526478000000001 3.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="3.0 3.0000000000000004 3.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %%
# h2o.get_atomic_numbers()
h2o.get_positions()
# Out:
# array([[3.      , 3.763239, 3.596309],
#        [3.      , 4.526478, 3.      ],
#        [3.      , 3.      , 3.      ]])

# %% [markdown]
# ### Step 2: optimize the atomic positions
#
# Start with the SCF relax calculation.

# %%
# create calculation folder and navigate into it
# %mkdir -p /content/water/
# %cd /content/water/

# create input and write it into the file h2.scf.in
qe_input = """
&control
  prefix='si',
  calculation='relax',
  verbosity='high',
  pseudo_dir = '/content/q-e/pseudopotentials/',
  outdir='/content/water/'
  forc_conv_thr=1.0e-3,
  tstress=true, ! to extract the stresses so we know how to change the cell parameters
  tprnfor=true, ! to extract the forces
/
&system
  occupations='fixed',
  ecutwfc = 30.0,
  ecutrho = 240.0,
  ibrav = 0,
  celldm(1) = 10,
  nat = 2,
  ntyp = 1,
/
&electrons
  conv_thr = 1e-12,
/
&ions
  ion_dynamics = 'bfgs',
/
ATOMIC_SPECIES
 H  1.00784  H.UPF
 O  15.999   O.UPF
ATOMIC_POSITIONS (angstrom)
 O 3.000000 3.763239 3.596309
 H 3.000000 4.526478 3.000000
 H 3.000000 3.000000 3.000000
K_POINTS (automatic)
  1 1 1 0 0 0
"""

with open("h2o.scf.in", "w") as f:
    f.write(qe_input)

# print the content of the input file (under Linux)
! cat h2o.scf.in
# Out:
# /content/water
#
# &control
#   prefix='h2o',
#   calculation='relax',
#   verbosity='high',
#   pseudo_dir = '/content/q-e/pseudopotentials/',
#   outdir='/content/water/'
#   forc_conv_thr=1.0e-3,
#   tstress=false,
#   tprnfor=true, ! to allow us to extract the forces
#   restart_mode='from_scratch',
# /
# &system
#   occupations='fixed',
#   assume_isolated='mt',
#   ecutwfc = 30.0,
#   ecutrho = 240.0,
#   ibrav = 1,
#   celldm(1) = 10,
#   nat = 3,
#   ntyp = 2,
# /
# &electrons
#   conv_thr = 1e-10,
# /
# &ions
#   ion_dynamics = 'bfgs',
# /
# ATOMIC_SPECIES
#  H  1.00784  H.UPF
#  O  15.999   O.UPF
# ATOMIC_POSITIONS (angstrom)
#  O 3.000000 3.763239 3.596309
#  H 3.000000 4.526478 3.000000
#  H 3.000000 3.000000 3.000000
# K_POINTS (automatic)
#   1 1 1 0 0 0

# %%
! /content/q-e/bin/pw.x -in h2o.scf.in > h2o.scf.out # run the relax calculation
! cat h2o.scf.out
# Out:
#      Program PWSCF v.7.4 starts on 14Dec2024 at  9:38:31
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#          "P. Giannozzi et al., J. Chem. Phys. 152 154105 (2020);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Serial version
#      9000 MiB available memory on the printing compute node when the environment starts
#
#      Reading input from h2o.scf.in
#
#      Current dimensions of program PWSCF are:
#      Max number of different atomic species (ntypx) = 10
#      Max number of k-points (npk) =  40000
#      Max angular momentum in pseudopotentials (lmaxx) =  4
#
#      File /content/water/h2o.update deleted, as requested
#
#      File /content/water/h2o.bfgs deleted, as requested
#      file H.UPF: wavefunction(s)  1S renormalized
#      file O.UPF: wavefunction(s)  2P renormalized
#
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum        1901     949    241                62669    22119    2777
#
#      Using Slab Decomposition
#
#
#
#      bravais-lattice index     =            1
#      lattice parameter (alat)  =      10.0000  a.u.
#      unit-cell volume          =    1000.0000 (a.u.)^3
#      number of atoms/cell      =            3
#      number of atomic types    =            2
#      number of electrons       =         8.00
#      number of Kohn-Sham states=            4
#      kinetic-energy cutoff     =      30.0000  Ry
#      charge density cutoff     =     240.0000  Ry
#      scf convergence threshold =      1.0E-10
#      mixing beta               =       0.7000
#      number of iterations used =            8  plain     mixing
#      energy convergence thresh.=      1.0E-04
#      force convergence thresh. =      1.0E-03
#      Exchange-correlation= SLA  PW   PBX  PBC
#                            (   1   4   3   4   0   0   0)
#      nstep                     =           50
#
#      Assuming isolated system, Martyna-Tuckerman method
#
#
#      celldm(1)=  10.000000  celldm(2)=   0.000000  celldm(3)=   0.000000
#      celldm(4)=   0.000000  celldm(5)=   0.000000  celldm(6)=   0.000000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (   1.000000   0.000000   0.000000 )
#                a(2) = (   0.000000   1.000000   0.000000 )
#                a(3) = (   0.000000   0.000000   1.000000 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  1.000000  0.000000  0.000000 )
#                b(2) = (  0.000000  1.000000  0.000000 )
#                b(3) = (  0.000000  0.000000  1.000000 )
#
#
#      PseudoPot. # 1 for H  read from file:
#      /content/q-e/pseudopotentials/H.UPF
#      MD5 check sum: fbb168fef676c0aaadbafd73f5b1efa8
#      Pseudo is Projector augmented-wave, Zval =  1.0
#      Generated using "atomic" code by A. Dal Corso  v.5.0.2 svn rev. 9415
#      Shape of augmentation charge: PSQ
#      Using radial grid of  929 points,  2 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#      Q(r) pseudized with 0 coefficients
#
#
#      PseudoPot. # 2 for O  read from file:
#      /content/q-e/pseudopotentials/O.UPF
#      MD5 check sum: 833c495a5d0f9b75bf046115549bffff
#      Pseudo is Projector augmented-wave + core cor, Zval =  6.0
#      Generated using &quot;atomic&quot; code by A. Dal Corso  v.6.3
#      Shape of augmentation charge: BESSEL
#      Using radial grid of 1095 points,  4 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#                 l(4) =   1
#      Q(r) pseudized with 0 coefficients
#
#
#      atomic species   valence    mass     pseudopotential
#      H                 1.00     1.00784     H ( 1.00)
#      O                 6.00    15.99900     O ( 1.00)
#
#      No symmetry found
#
#
#                                     s                        frac. trans.
#
#       isym =  1     identity
#
#  cryst.   s( 1) = (     1          0          0      )
#                   (     0          1          0      )
#                   (     0          0          1      )
#
#  cart.    s( 1) = (  1.0000000  0.0000000  0.0000000 )
#                   (  0.0000000  1.0000000  0.0000000 )
#                   (  0.0000000  0.0000000  1.0000000 )
#
#
#      point group C_1 (1)
#      there are  1 classes
#      the character table:
#
#        E
# A      1.00
#
#      the symmetry operations in each class and the name of the first element:
#
#      E        1
#           identity
#
#    Cartesian axes
#
#      site n.     atom                  positions (alat units)
#          1        O      tau(   1) = (   0.5669178   0.7111491   0.6796039  )
#          2        H      tau(   2) = (   0.5669178   0.8553804   0.5669178  )
#          3        H      tau(   3) = (   0.5669178   0.5669178   0.5669178  )
#
#    Crystallographic axes
#
#      site n.     atom                  positions (cryst. coord.)
#          1        O      tau(   1) = (  0.5669178  0.7111491  0.6796039  )
#          2        H      tau(   2) = (  0.5669178  0.8553804  0.5669178  )
#          3        H      tau(   3) = (  0.5669178  0.5669178  0.5669178  )
#
#      number of k points=     1
#                        cart. coord. in units 2pi/alat
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   2.0000000
#
#                        cryst. coord.
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   2.0000000
#
#      Dense  grid:    62669 G-vectors     FFT dimensions: (  50,  50,  50)
#
#      Smooth grid:    22119 G-vectors     FFT dimensions: (  36,  36,  36)
#
#      Dynamical RAM for                 wfc:       0.17 MB
#
#      Dynamical RAM for     wfc (w. buffer):       0.17 MB
#
#      Dynamical RAM for           str. fact:       1.91 MB
#
#      Dynamical RAM for           local pot:       0.00 MB
#
#      Dynamical RAM for          nlocal pot:       0.51 MB
#
#      Dynamical RAM for                qrad:       0.71 MB
#
#      Dynamical RAM for          rho,v,vnew:       5.73 MB
#
#      Dynamical RAM for               rhoin:       1.91 MB
#
#      Dynamical RAM for            rho*nmix:      15.30 MB
#
#      Dynamical RAM for           G-vectors:       3.75 MB
#
#      Dynamical RAM for          h,s,v(r/c):       0.00 MB
#
#      Dynamical RAM for          <psi|beta>:       0.00 MB
#
#      Dynamical RAM for                 psi:       0.34 MB
#
#      Dynamical RAM for                hpsi:       0.34 MB
#
#      Dynamical RAM for                spsi:       0.34 MB
#
#      Dynamical RAM for      wfcinit/wfcrot:       0.34 MB
#
#      Dynamical RAM for           addusdens:      43.03 MB
#
#      Dynamical RAM for          addusforce:      45.42 MB
#
#      Estimated static dynamical RAM per process >      22.33 MB
#
#      Estimated max dynamical RAM per process >      83.06 MB
#
#      Check: negative core charge=   -0.000005
#
#      Initial potential from superposition of free atoms
#
#      starting charge       8.0000, renormalised to       8.0000
#
#      negative rho (up, down):  6.693E-06 0.000E+00
#      Starting wfcs are    6 randomized atomic wfcs
#
#      total cpu time spent up to now is        1.3 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#             85 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8941 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.00E-02,  avg # of iterations =  2.0
#
#      negative rho (up, down):  6.990E-05 0.000E+00
#
#      total cpu time spent up to now is        1.6 secs
#
#      total energy              =     -43.78273535 Ry
#      estimated scf accuracy    <       0.41043320 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#             97 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8936 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  5.13E-03,  avg # of iterations =  2.0
#
#      negative rho (up, down):  8.906E-05 0.000E+00
#
#      total cpu time spent up to now is        1.9 secs
#
#      total energy              =     -43.92073999 Ry
#      estimated scf accuracy    <       0.25422273 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            100 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8941 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.18E-03,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.255E-04 0.000E+00
#
#      total cpu time spent up to now is        2.3 secs
#
#      total energy              =     -43.94937761 Ry
#      estimated scf accuracy    <       0.01188338 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            101 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8939 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.49E-04,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.851E-04 0.000E+00
#
#      total cpu time spent up to now is        2.7 secs
#
#      total energy              =     -43.95617789 Ry
#      estimated scf accuracy    <       0.01956253 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            101 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8922 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.49E-04,  avg # of iterations =  2.0
#
#      negative rho (up, down):  2.077E-04 0.000E+00
#
#      total cpu time spent up to now is        3.2 secs
#
#      total energy              =     -43.95798515 Ry
#      estimated scf accuracy    <       0.00144642 Ry
#
#      iteration #  6     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            102 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8921 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.81E-05,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.981E-04 0.000E+00
#
#      total cpu time spent up to now is        3.6 secs
#
#      total energy              =     -43.95876266 Ry
#      estimated scf accuracy    <       0.00008184 Ry
#
#      iteration #  7     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            103 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8920 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.02E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.933E-04 0.000E+00
#
#      total cpu time spent up to now is        4.1 secs
#
#      total energy              =     -43.95875701 Ry
#      estimated scf accuracy    <       0.00005762 Ry
#
#      iteration #  8     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            103 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8919 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  7.20E-07,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.921E-04 0.000E+00
#
#      total cpu time spent up to now is        4.5 secs
#
#      total energy              =     -43.95875697 Ry
#      estimated scf accuracy    <       0.00001456 Ry
#
#      iteration #  9     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            104 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8923 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.82E-07,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.909E-04 0.000E+00
#
#      total cpu time spent up to now is        5.0 secs
#
#      total energy              =     -43.95875795 Ry
#      estimated scf accuracy    <       0.00000249 Ry
#
#      iteration # 10     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8922 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.12E-08,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.917E-04 0.000E+00
#
#      total cpu time spent up to now is        5.5 secs
#
#      total energy              =     -43.95875948 Ry
#      estimated scf accuracy    <       0.00000063 Ry
#
#      iteration # 11     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8922 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  7.87E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.922E-04 0.000E+00
#
#      total cpu time spent up to now is        5.9 secs
#
#      total energy              =     -43.95875930 Ry
#      estimated scf accuracy    <       0.00000031 Ry
#
#      iteration # 12     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8936 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.89E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.921E-04 0.000E+00
#
#      total cpu time spent up to now is        6.2 secs
#
#      total energy              =     -43.95875943 Ry
#      estimated scf accuracy    <       0.00000004 Ry
#
#      iteration # 13     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8935 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  5.59E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.920E-04 0.000E+00
#
#      total cpu time spent up to now is        6.5 secs
#
#      total energy              =     -43.95875943 Ry
#      estimated scf accuracy    <       0.00000001 Ry
#
#      iteration # 14     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8935 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.54E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.920E-04 0.000E+00
#
#      total cpu time spent up to now is        6.8 secs
#
#      total energy              =     -43.95875943 Ry
#      estimated scf accuracy    <          2.3E-10 Ry
#
#      iteration # 15     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8935 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.84E-12,  avg # of iterations =  4.0
#
#      negative rho (up, down):  1.920E-04 0.000E+00
#
#      total cpu time spent up to now is        7.1 secs
#
#      total energy              =     -43.95875943 Ry
#      estimated scf accuracy    <          1.7E-09 Ry
#
#      iteration # 16     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8911 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.84E-12,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.921E-04 0.000E+00
#
#      total cpu time spent up to now is        7.4 secs
#
#      total energy              =     -43.95875943 Ry
#      estimated scf accuracy    <          2.0E-09 Ry
#
#      iteration # 17     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8911 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.84E-12,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.920E-04 0.000E+00
#
#      total cpu time spent up to now is        7.7 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  2777 PWs)   bands (ev):
#
#    -25.2464 -12.8743  -9.1227  -6.9928
#
#      occupation numbers
#      1.0000   1.0000   1.0000   1.0000
#
#      highest occupied level (ev):    -6.9928
#
# !    total energy              =     -43.95875943 Ry
#      total all-electron energy =      -152.805643 Ry
#      estimated scf accuracy    <          7.7E-11 Ry
#
#      The total energy is the sum of the following terms:
#      one-electron contribution =     -82.05716698 Ry
#      hartree contribution      =      42.65174234 Ry
#      xc contribution           =      -8.84301273 Ry
#      ewald contribution        =      13.80577339 Ry
#      one-center paw contrib.   =      -9.51609544 Ry
#       -> PAW hartree energy AE =      33.11137884 Ry
#       -> PAW hartree energy PS =     -33.00042403 Ry
#       -> PAW xc energy AE      =     -18.81976723 Ry
#       -> PAW xc energy PS      =       9.19271698 Ry
#       -> total E_H with PAW    =      42.76269715 Ry
#       -> total E_XC with PAW   =     -18.47006298 Ry
#
#      convergence has been achieved in  17 iterations
#
#      negative rho (up, down):  1.920E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  2   force =     0.00000321    0.00000209    0.01611271
#      atom    2 type  1   force =    -0.00000166    0.01178342   -0.00805638
#      atom    3 type  1   force =    -0.00000154   -0.01178551   -0.00805633
#      The Martyna-Tuckerman correction term to forces
#      atom    1 type  2   force =     0.00000006   -0.00000001    0.03330714
#      atom    2 type  1   force =     0.00000001    0.00408703    0.00536569
#      atom    3 type  1   force =     0.00000001   -0.00408703    0.00536569
#      The non-local contrib.  to forces
#      atom    1 type  2   force =     0.00000215   -0.00000427   -2.49165256
#      atom    2 type  1   force =    -0.00000247   -0.09191381    0.06647359
#      atom    3 type  1   force =    -0.00000240    0.09191410    0.06647352
#      The ionic contribution  to forces
#      atom    1 type  2   force =     0.00000000    0.00000000    4.30373308
#      atom    2 type  1   force =     0.00000000    2.95984538   -2.15186654
#      atom    3 type  1   force =    -0.00000000   -2.95984538   -2.15186654
#      The local contribution  to forces
#      atom    1 type  2   force =    -0.00000407    0.00000037   -1.85392496
#      atom    2 type  1   force =    -0.00000028   -2.86023577    2.07197317
#      atom    3 type  1   force =    -0.00000023    2.86023605    2.07197330
#      The core correction contribution to forces
#      atom    1 type  2   force =     0.00000398    0.00000744    0.02465537
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The Hubbard contrib.    to forces
#      atom    1 type  2   force =     0.00000000    0.00000000    0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The SCF correction term to forces
#      atom    1 type  2   force =     0.00000001   -0.00000011   -0.00000498
#      atom    2 type  1   force =     0.00000000    0.00000192   -0.00000192
#      atom    3 type  1   force =    -0.00000000   -0.00000193   -0.00000191
#
#      Total force =     0.025830     Total SCF correction =     0.000006
#
#      BFGS Geometry Optimization
#      Energy error            =      6.7E-04 Ry
#      Gradient error          =      1.6E-02 Ry/Bohr
#
#      number of scf cycles    =   1
#      number of bfgs steps    =   0
#
#      energy             new  =     -43.9587594310 Ry
#
#      new trust radius        =       0.0161127137 bohr
#      new conv_thr            =            1.0E-10 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                3.0000016982        3.7632401071        3.6048354807
# H                2.9999991191        4.5327135168        2.9957367448
# H                2.9999991827        2.9937633761        2.9957367745
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000005
#
#      negative rho (up, down):  1.791E-04 0.000E+00
#
#      total cpu time spent up to now is        8.2 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8948 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.00E-06,  avg # of iterations =  6.0
#
#      negative rho (up, down):  1.795E-04 0.000E+00
#
#      total cpu time spent up to now is        8.5 secs
#
#      total energy              =     -43.95875174 Ry
#      estimated scf accuracy    <       0.00030217 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8961 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.78E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.834E-04 0.000E+00
#
#      total cpu time spent up to now is        8.8 secs
#
#      total energy              =     -43.95883821 Ry
#      estimated scf accuracy    <       0.00015967 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8961 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.00E-06,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.874E-04 0.000E+00
#
#      total cpu time spent up to now is        9.1 secs
#
#      total energy              =     -43.95886214 Ry
#      estimated scf accuracy    <       0.00000320 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8975 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  4.01E-08,  avg # of iterations =  4.0
#
#      negative rho (up, down):  1.857E-04 0.000E+00
#
#      total cpu time spent up to now is        9.4 secs
#
#      total energy              =     -43.95886505 Ry
#      estimated scf accuracy    <       0.00000667 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8974 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  4.01E-08,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.855E-04 0.000E+00
#
#      total cpu time spent up to now is        9.7 secs
#
#      total energy              =     -43.95886553 Ry
#      estimated scf accuracy    <       0.00000050 Ry
#
#      iteration #  6     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8973 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  6.30E-09,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.859E-04 0.000E+00
#
#      total cpu time spent up to now is       10.0 secs
#
#      total energy              =     -43.95886579 Ry
#      estimated scf accuracy    <       0.00000012 Ry
#
#      iteration #  7     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8973 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.49E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.860E-04 0.000E+00
#
#      total cpu time spent up to now is       10.3 secs
#
#      total energy              =     -43.95886578 Ry
#      estimated scf accuracy    <       0.00000004 Ry
#
#      iteration #  8     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8972 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  4.43E-10,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.860E-04 0.000E+00
#
#      total cpu time spent up to now is       10.7 secs
#
#      total energy              =     -43.95886580 Ry
#      estimated scf accuracy    <          3.5E-09 Ry
#
#      iteration #  9     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            105 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  4.35E-11,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.860E-04 0.000E+00
#
#      total cpu time spent up to now is       11.0 secs
#
#      total energy              =     -43.95886580 Ry
#      estimated scf accuracy    <          1.6E-09 Ry
#
#      iteration # 10     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            106 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.04E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.860E-04 0.000E+00
#
#      total cpu time spent up to now is       11.3 secs
#
#      total energy              =     -43.95886580 Ry
#      estimated scf accuracy    <          5.2E-10 Ry
#
#      iteration # 11     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  6.56E-12,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.860E-04 0.000E+00
#
#      total cpu time spent up to now is       11.6 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  2777 PWs)   bands (ev):
#
#    -25.1152 -12.7200  -9.1375  -6.9653
#
#      occupation numbers
#      1.0000   1.0000   1.0000   1.0000
#
#      highest occupied level (ev):    -6.9653
#
# !    total energy              =     -43.95886580 Ry
#      total all-electron energy =      -152.805749 Ry
#      estimated scf accuracy    <          6.0E-11 Ry
#
#      The total energy is the sum of the following terms:
#      one-electron contribution =     -81.76393446 Ry
#      hartree contribution      =      42.51378407 Ry
#      xc contribution           =      -8.82008563 Ry
#      ewald contribution        =      13.62902167 Ry
#      one-center paw contrib.   =      -9.51765144 Ry
#       -> PAW hartree energy AE =      32.73480510 Ry
#       -> PAW hartree energy PS =     -32.62551658 Ry
#       -> PAW xc energy AE      =     -18.73266907 Ry
#       -> PAW xc energy PS      =       9.10572910 Ry
#       -> total E_H with PAW    =      42.62307259 Ry
#       -> total E_XC with PAW   =     -18.44702560 Ry
#
#      convergence has been achieved in  11 iterations
#
#      negative rho (up, down):  1.860E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  2   force =     0.00000321   -0.00000207   -0.01263975
#      atom    2 type  1   force =    -0.00000174   -0.00576501    0.00631828
#      atom    3 type  1   force =    -0.00000147    0.00576708    0.00632147
#      The Martyna-Tuckerman correction term to forces
#      atom    1 type  2   force =     0.00000016    0.00000013    0.03355620
#      atom    2 type  1   force =     0.00000003    0.00421982    0.00538581
#      atom    3 type  1   force =     0.00000003   -0.00421978    0.00538581
#      The non-local contrib.  to forces
#      atom    1 type  2   force =    -0.00000807   -0.00000529   -2.50144431
#      atom    2 type  1   force =    -0.00000225   -0.08720894    0.06391989
#      atom    3 type  1   force =    -0.00000206    0.08720849    0.06391914
#      The ionic contribution  to forces
#      atom    1 type  2   force =     0.00001770   -0.00001017    4.22193220
#      atom    2 type  1   force =    -0.00000897    2.86822082   -2.11097469
#      atom    3 type  1   force =    -0.00000873   -2.86821065   -2.11095751
#      The local contribution  to forces
#      atom    1 type  2   force =    -0.00001133    0.00000869   -1.79177115
#      atom    2 type  1   force =     0.00000837   -2.79099713    2.04798808
#      atom    3 type  1   force =     0.00000822    2.79099182    2.04797483
#      The core correction contribution to forces
#      atom    1 type  2   force =     0.00000367    0.00000576    0.02509338
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The Hubbard contrib.    to forces
#      atom    1 type  2   force =     0.00000000    0.00000000    0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The SCF correction term to forces
#      atom    1 type  2   force =    -0.00000000    0.00000000   -0.00000700
#      atom    2 type  1   force =     0.00000000    0.00000160   -0.00000174
#      atom    3 type  1   force =     0.00000000   -0.00000160   -0.00000174
#
#      Total force =     0.017497     Total SCF correction =     0.000008
#      Energy error            =      1.1E-04 Ry
#      Gradient error          =      1.3E-02 Ry/Bohr
#
#      number of scf cycles    =   2
#      number of bfgs steps    =   1
#
#      energy             old  =     -43.9587594310 Ry
#      energy             new  =     -43.9588657965 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0074835120 bohr
#      new conv_thr            =            1.1E-12 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                3.0000027336        3.7632394563        3.6008753769
# H                2.9999985576        4.5309252989        2.9977162894
# H                2.9999987088        2.9955522448        2.9977173337
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000005
#
#      negative rho (up, down):  1.914E-04 0.000E+00
#
#      total cpu time spent up to now is       12.0 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8978 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.00E-06,  avg # of iterations =  4.0
#
#      negative rho (up, down):  1.908E-04 0.000E+00
#
#      total cpu time spent up to now is       12.4 secs
#
#      total energy              =     -43.95894189 Ry
#      estimated scf accuracy    <       0.00004560 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8976 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  5.70E-07,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.891E-04 0.000E+00
#
#      total cpu time spent up to now is       12.7 secs
#
#      total energy              =     -43.95895585 Ry
#      estimated scf accuracy    <       0.00002474 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8975 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.09E-07,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.875E-04 0.000E+00
#
#      total cpu time spent up to now is       13.0 secs
#
#      total energy              =     -43.95895928 Ry
#      estimated scf accuracy    <       0.00000074 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8975 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  9.26E-09,  avg # of iterations =  4.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       13.3 secs
#
#      total energy              =     -43.95895996 Ry
#      estimated scf accuracy    <       0.00000189 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8974 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  9.26E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.887E-04 0.000E+00
#
#      total cpu time spent up to now is       13.6 secs
#
#      total energy              =     -43.95895998 Ry
#      estimated scf accuracy    <       0.00000025 Ry
#
#      iteration #  6     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8973 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.13E-09,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.886E-04 0.000E+00
#
#      total cpu time spent up to now is       13.9 secs
#
#      total energy              =     -43.95896012 Ry
#      estimated scf accuracy    <       0.00000006 Ry
#
#      iteration #  7     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8973 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  7.80E-10,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       14.2 secs
#
#      total energy              =     -43.95896010 Ry
#      estimated scf accuracy    <       0.00000005 Ry
#
#      iteration #  8     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8972 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  5.78E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       14.5 secs
#
#      total energy              =     -43.95896011 Ry
#      estimated scf accuracy    <          4.5E-09 Ry
#
#      iteration #  9     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  5.62E-11,  avg # of iterations =  4.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       14.8 secs
#
#      total energy              =     -43.95896011 Ry
#      estimated scf accuracy    <          1.5E-09 Ry
#
#      iteration # 10     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.84E-11,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       15.1 secs
#
#      total energy              =     -43.95896011 Ry
#      estimated scf accuracy    <          1.8E-09 Ry
#
#      iteration # 11     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.84E-11,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       15.4 secs
#
#      total energy              =     -43.95896011 Ry
#      estimated scf accuracy    <          1.0E-09 Ry
#
#      iteration # 12     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.28E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       15.7 secs
#
#      total energy              =     -43.95896011 Ry
#      estimated scf accuracy    <          2.8E-11 Ry
#
#      iteration # 13     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8971 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  3.48E-13,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       16.1 secs
#
#      total energy              =     -43.95896011 Ry
#      estimated scf accuracy    <          1.8E-11 Ry
#
#      iteration # 14     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8959 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.19E-13,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       16.6 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  2777 PWs)   bands (ev):
#
#    -25.1644 -12.7869  -9.1250  -6.9754
#
#      occupation numbers
#      1.0000   1.0000   1.0000   1.0000
#
#      highest occupied level (ev):    -6.9754
#
# !    total energy              =     -43.95896011 Ry
#      total all-electron energy =      -152.805843 Ry
#      estimated scf accuracy    <          2.2E-13 Ry
#
#      The total energy is the sum of the following terms:
#      one-electron contribution =     -81.87893677 Ry
#      hartree contribution      =      42.56804429 Ry
#      xc contribution           =      -8.82907872 Ry
#      ewald contribution        =      13.69799852 Ry
#      one-center paw contrib.   =      -9.51698742 Ry
#       -> PAW hartree energy AE =      32.88312992 Ry
#       -> PAW hartree energy PS =     -32.77315171 Ry
#       -> PAW xc energy AE      =     -18.76675127 Ry
#       -> PAW xc energy PS      =       9.13978564 Ry
#       -> total E_H with PAW    =      42.67802249 Ry
#       -> total E_XC with PAW   =     -18.45604435 Ry
#
#      convergence has been achieved in  14 iterations
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  2   force =     0.00000324    0.00000141   -0.00103813
#      atom    2 type  1   force =    -0.00000177    0.00066171    0.00051870
#      atom    3 type  1   force =    -0.00000147   -0.00066312    0.00051943
#      The Martyna-Tuckerman correction term to forces
#      atom    1 type  2   force =     0.00000025    0.00000006    0.03340833
#      atom    2 type  1   force =     0.00000005    0.00417956    0.00537247
#      atom    3 type  1   force =     0.00000005   -0.00417953    0.00537246
#      The non-local contrib.  to forces
#      atom    1 type  2   force =    -0.00001413   -0.00000609   -2.49628475
#      atom    2 type  1   force =    -0.00000210   -0.08913998    0.06480455
#      atom    3 type  1   force =    -0.00000188    0.08914013    0.06480433
#      The ionic contribution  to forces
#      atom    1 type  2   force =     0.00002895    0.00000111    4.24812794
#      atom    2 type  1   force =    -0.00001476    2.90601874   -2.12406739
#      atom    3 type  1   force =    -0.00001419   -2.90601985   -2.12406055
#      The local contribution  to forces
#      atom    1 type  2   force =    -0.00001645    0.00000070   -1.81120864
#      atom    2 type  1   force =     0.00001394   -2.82039533    2.05440662
#      atom    3 type  1   force =     0.00001345    2.82039750    2.05440074
#      The core correction contribution to forces
#      atom    1 type  2   force =     0.00000353    0.00000696    0.02491692
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The Hubbard contrib.    to forces
#      atom    1 type  2   force =     0.00000000    0.00000000    0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The SCF correction term to forces
#      atom    1 type  2   force =    -0.00000000   -0.00000000   -0.00000047
#      atom    2 type  1   force =    -0.00000000    0.00000004   -0.00000009
#      atom    3 type  1   force =     0.00000000   -0.00000004   -0.00000009
#
#      Total force =     0.001579     Total SCF correction =     0.000000
#      Energy error            =      9.4E-05 Ry
#      Gradient error          =      1.0E-03 Ry/Bohr
#
#      number of scf cycles    =   3
#      number of bfgs steps    =   2
#
#      energy             old  =     -43.9588657965 Ry
#      energy             new  =     -43.9589601100 Ry
#
#      CASE: energy            _new < energy            _old
#
#      new trust radius        =       0.0009752923 bohr
#      new conv_thr            =            1.0E-12 Ry
#
#
# ATOMIC_POSITIONS (angstrom)
# O                3.0000045279        3.7632402419        3.6003592781
# H                2.9999975774        4.5313281292        2.9979741376
# H                2.9999978947        2.9951486289        2.9979755843
#
#
#
#      Writing config-only to output data dir /content/water/h2o.save/ :
#      XML data file
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative core charge=   -0.000005
#
#      negative rho (up, down):  1.884E-04 0.000E+00
#
#      total cpu time spent up to now is       17.3 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8965 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.00E-06,  avg # of iterations =  2.0
#
#      Threshold (ethr) on eigenvalues was too large:
#      Diagonalizing with lowered threshold
#
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8964 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.79E-09,  avg # of iterations =  4.0
#
#      negative rho (up, down):  1.886E-04 0.000E+00
#
#      total cpu time spent up to now is       17.9 secs
#
#      total energy              =     -43.95896209 Ry
#      estimated scf accuracy    <       0.00000017 Ry
#
#      iteration #  2     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8976 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.12E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       18.4 secs
#
#      total energy              =     -43.95896212 Ry
#      estimated scf accuracy    <       0.00000006 Ry
#
#      iteration #  3     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8963 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  7.20E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       18.8 secs
#
#      total energy              =     -43.95896214 Ry
#      estimated scf accuracy    <          1.9E-09 Ry
#
#      iteration #  4     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8961 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.41E-11,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       19.2 secs
#
#      total energy              =     -43.95896214 Ry
#      estimated scf accuracy    <          2.7E-09 Ry
#
#      iteration #  5     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8961 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.41E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       19.5 secs
#
#      total energy              =     -43.95896213 Ry
#      estimated scf accuracy    <          2.1E-10 Ry
#
#      iteration #  6     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8957 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.68E-12,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       19.9 secs
#
#      total energy              =     -43.95896214 Ry
#      estimated scf accuracy    <          9.5E-11 Ry
#
#      iteration #  7     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8957 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.19E-12,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       20.2 secs
#
#      total energy              =     -43.95896214 Ry
#      estimated scf accuracy    <          2.4E-11 Ry
#
#      iteration #  8     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8956 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  2.99E-13,  avg # of iterations =  3.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       20.5 secs
#
#      total energy              =     -43.95896214 Ry
#      estimated scf accuracy    <          6.4E-12 Ry
#
#      iteration #  9     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8955 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.00E-13,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       20.8 secs
#
#      total energy              =     -43.95896214 Ry
#      estimated scf accuracy    <          3.5E-12 Ry
#
#      iteration # 10     ecut=    30.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#
# ---- Real-time Memory Report at c_bands before calling an iterative solver
#            107 MiB given to the printing process from OS
#              0 MiB allocation reported by mallinfo(arena+hblkhd)
#           8954 MiB available memory on the node where the printing process lives
# ------------------
#      ethr =  1.00E-13,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      total cpu time spent up to now is       21.1 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  2777 PWs)   bands (ev):
#
#    -25.1643 -12.7932  -9.1202  -6.9753
#
#      occupation numbers
#      1.0000   1.0000   1.0000   1.0000
#
#      highest occupied level (ev):    -6.9753
#
# !    total energy              =     -43.95896214 Ry
#      total all-electron energy =      -152.805845 Ry
#      estimated scf accuracy    <          3.4E-13 Ry
#
#      The total energy is the sum of the following terms:
#      one-electron contribution =     -81.88213463 Ry
#      hartree contribution      =      42.56967160 Ry
#      xc contribution           =      -8.82934577 Ry
#      ewald contribution        =      13.69978001 Ry
#      one-center paw contrib.   =      -9.51693334 Ry
#       -> PAW hartree energy AE =      32.88857035 Ry
#       -> PAW hartree energy PS =     -32.77854576 Ry
#       -> PAW xc energy AE      =     -18.76782141 Ry
#       -> PAW xc energy PS      =       9.14086347 Ry
#       -> total E_H with PAW    =      42.67969619 Ry
#       -> total E_XC with PAW   =     -18.45630370 Ry
#
#      convergence has been achieved in  10 iterations
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  2   force =     0.00000329   -0.00000096   -0.00038515
#      atom    2 type  1   force =    -0.00000179    0.00063915    0.00019130
#      atom    3 type  1   force =    -0.00000150   -0.00063820    0.00019385
#      The Martyna-Tuckerman correction term to forces
#      atom    1 type  2   force =     0.00000037    0.00000013    0.03337034
#      atom    2 type  1   force =     0.00000007    0.00418706    0.00536827
#      atom    3 type  1   force =     0.00000007   -0.00418702    0.00536825
#      The non-local contrib.  to forces
#      atom    1 type  2   force =    -0.00002539   -0.00000790   -2.49505876
#      atom    2 type  1   force =    -0.00000179   -0.08926423    0.06475107
#      atom    3 type  1   force =    -0.00000161    0.08926394    0.06475026
#      The ionic contribution  to forces
#      atom    1 type  2   force =     0.00004798   -0.00000435    4.24484903
#      atom    2 type  1   force =    -0.00002459    2.90852207   -2.12243406
#      atom    3 type  1   force =    -0.00002338   -2.90851772   -2.12241497
#      The local contribution  to forces
#      atom    1 type  2   force =    -0.00002448    0.00000545   -1.80845441
#      atom    2 type  1   force =     0.00002343   -2.82280432    2.05250356
#      atom    3 type  1   force =     0.00002233    2.82280378    2.05248785
#      The core correction contribution to forces
#      atom    1 type  2   force =     0.00000371    0.00000701    0.02490579
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The Hubbard contrib.    to forces
#      atom    1 type  2   force =     0.00000000    0.00000000    0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    3 type  1   force =     0.00000000    0.00000000    0.00000000
#      The SCF correction term to forces
#      atom    1 type  2   force =     0.00000000   -0.00000000    0.00000053
#      atom    2 type  1   force =     0.00000000   -0.00000012    0.00000013
#      atom    3 type  1   force =     0.00000000    0.00000012    0.00000013
#
#      Total force =     0.001019     Total SCF correction =     0.000001
#      Energy error            =      2.0E-06 Ry
#      Gradient error          =      6.4E-04 Ry/Bohr
#
#      bfgs converged in   4 scf cycles and   3 bfgs steps
#      (criteria: energy <  1.0E-04 Ry, force <  1.0E-03 Ry/Bohr)
#
#      End of BFGS Geometry Optimization
#
#      Final energy             =     -43.9589621352 Ry
#
#      File /content/water/h2o.bfgs deleted, as requested
# Begin final coordinates
#
# ATOMIC_POSITIONS (angstrom)
# O                3.0000045279        3.7632402419        3.6003592781
# H                2.9999975774        4.5313281292        2.9979741376
# H                2.9999978947        2.9951486289        2.9979755843
# End final coordinates
#
#
#
#      Writing all to output data dir /content/water/h2o.save/ :
#      XML data file, charge density, pseudopotentials, collected wavefunctions
#
#      init_run     :      1.05s CPU      1.12s WALL (       1 calls)
#      electrons    :     14.90s CPU     18.18s WALL (       4 calls)
#      update_pot   :      0.42s CPU      0.45s WALL (       3 calls)
#      forces       :      0.75s CPU      0.94s WALL (       4 calls)
#
#      Called by init_run:
#      wfcinit      :      0.18s CPU      0.18s WALL (       1 calls)
#      wfcinit:atom :      0.00s CPU      0.00s WALL (       1 calls)
#      wfcinit:wfcr :      0.17s CPU      0.18s WALL (       1 calls)
#      potinit      :      0.35s CPU      0.38s WALL (       1 calls)
#      hinit0       :      0.44s CPU      0.45s WALL (       1 calls)
#
#      Called by electrons:
#      c_bands      :      0.89s CPU      0.93s WALL (      53 calls)
#      sum_band     :      3.70s CPU      5.14s WALL (      53 calls)
#      v_of_rho     :      3.90s CPU      4.23s WALL (      56 calls)
#      v_h          :      0.30s CPU      0.32s WALL (      56 calls)
#      v_xc         :      3.84s CPU      4.20s WALL (      60 calls)
#      newd         :      3.19s CPU      4.61s WALL (      56 calls)
#      PAW_pot      :      3.25s CPU      3.43s WALL (      59 calls)
#      mix_rho      :      0.46s CPU      0.47s WALL (      53 calls)
#
#      Called by c_bands:
#      init_us_2    :      0.08s CPU      0.08s WALL (     114 calls)
#      cegterg      :      0.83s CPU      0.85s WALL (      53 calls)
#
#      Called by sum_band:
#      sum_band:wei :      0.00s CPU      0.00s WALL (      53 calls)
#      sum_band:loo :      0.14s CPU      0.15s WALL (      53 calls)
#      sum_band:buf :      0.00s CPU      0.00s WALL (      53 calls)
#      sum_band:ini :      0.04s CPU      0.04s WALL (      53 calls)
#      sum_band:cal :      0.01s CPU      0.01s WALL (      56 calls)
#      sum_band:bec :      0.00s CPU      0.00s WALL (      56 calls)
#      addusdens    :      3.35s CPU      4.78s WALL (      53 calls)
#                                         0.00s GPU  (      53 calls)
#      addusd:skk   :      0.05s CPU      0.06s WALL (     106 calls)
#                                         0.00s GPU  (     106 calls)
#
#      Called by *egterg:
#      cdiaghg      :      0.02s CPU      0.02s WALL (     173 calls)
#      cegterg:over :      0.02s CPU      0.02s WALL (     124 calls)
#      cegterg:upda :      0.02s CPU      0.02s WALL (     124 calls)
#      cegterg:last :      0.02s CPU      0.02s WALL (     123 calls)
#      h_psi        :      0.89s CPU      0.91s WALL (     178 calls)
#      s_psi        :      0.02s CPU      0.02s WALL (     178 calls)
#      g_psi        :      0.01s CPU      0.01s WALL (     124 calls)
#
#      Called by h_psi:
#      h_psi:calbec :      0.02s CPU      0.02s WALL (     178 calls)
#      vloc_psi     :      0.84s CPU      0.86s WALL (     178 calls)
#      add_vuspsi   :      0.02s CPU      0.02s WALL (     178 calls)
#
#      General routines
#      calbec       :      0.03s CPU      0.03s WALL (     250 calls)
#      fft          :      1.71s CPU      1.75s WALL (     772 calls)
#      ffts         :      0.27s CPU      0.28s WALL (     109 calls)
#      fftw         :      0.75s CPU      0.77s WALL (    1522 calls)
#      interpolate  :      0.38s CPU      0.39s WALL (      56 calls)
#
#
#      PAW routines
#      PAW_pot      :      3.25s CPU      3.43s WALL (      59 calls)
#
#      PWSCF        :     17.63s CPU     21.30s WALL
#
#
#    This run was terminated on:   9:38:52  14Dec2024
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=

# %% [markdown]
# ### Step 3: calculate vibrational modes and effective charges

# %%
ph_inputs = """
&INPUTPH
  tr2_ph=1.0e-15,
  prefix='h2o',
  verbosity='high',
  epsil=.true.
  alpha_mix(1)=0.4
  ldisp=.true
  nq1=1
  nq2=1
  nq3=1
/
"""

with open('h2o.ph.in', 'w+') as handle:
    handle.write(ph_inputs)

! /content/q-e/bin/ph.x -in h2o.ph.in > h2o.ph.out # run the ph.x executable

! cat h2o.ph.out
# Out:
#      Program PHONON v.7.4 starts on 14Dec2024 at  9:39:15
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#          "P. Giannozzi et al., J. Chem. Phys. 152 154105 (2020);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Serial version
#      9018 MiB available memory on the printing compute node when the environment starts
#
#      Reading input from h2o.ph.in
#
#      Reading xml data from directory:
#
#      ./h2o.save/
#
#      file H.UPF: wavefunction(s)  1S renormalized
#      file O.UPF: wavefunction(s)  2P renormalized
#
#      IMPORTANT: XC functional enforced from input :
#      Exchange-correlation= PBE
#                            (   1   4   3   4   0   0   0)
#      Any further DFT definition will be discarded
#      Please, verify this is what you really want
#
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum        1901     949    241                62669    22119    2777
#
#      Using Slab Decomposition
#
#
#      Check: negative core charge=   -0.000005
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#      Reading collected, re-writing distributed wavefunctions in ./
#
#
#      Dynamical matrices for ( 1, 1, 1)  uniform grid of q-points
#      (   1 q-points):
#        N         xq(1)         xq(2)         xq(3)
#        1   0.000000000   0.000000000   0.000000000
#
#      Number and degeneracy of irreps per q-point
#        N         xq(1)         xq(2)         xq(3)   N irreps
#        1   0.000000000   0.000000000   0.000000000       9
#      No degeneracy
#
#      Calculation of q =    0.0000000   0.0000000   0.0000000
#
#
#
#      bravais-lattice index     =            1
#      lattice parameter (alat)  =      10.0000  a.u.
#      unit-cell volume          =    1000.0000 (a.u.)^3
#      number of atoms/cell      =            3
#      number of atomic types    =            2
#      kinetic-energy cut-off    =      30.0000  Ry
#      charge density cut-off    =     240.0000  Ry
#      convergence threshold     =      1.0E-15
#      beta                      =       0.4000
#      number of iterations used =            4
#      Exchange-correlation= PBE
#                            (   1   4   3   4   0   0   0)
#
#
#      celldm(1)=   10.00000  celldm(2)=    0.00000  celldm(3)=    0.00000
#      celldm(4)=    0.00000  celldm(5)=    0.00000  celldm(6)=    0.00000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (  1.0000  0.0000  0.0000 )
#                a(2) = (  0.0000  1.0000  0.0000 )
#                a(3) = (  0.0000  0.0000  1.0000 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  1.0000  0.0000  0.0000 )
#                b(2) = (  0.0000  1.0000  0.0000 )
#                b(3) = (  0.0000  0.0000  1.0000 )
#
#
#      Atoms inside the unit cell:
#
#      Cartesian axes
#
#      site n.  atom      mass           positions (alat units)
#         1  O      15.9990   tau(    1) = (    0.56692    0.71115    0.68037  )
#         2  H       1.0078   tau(    2) = (    0.56692    0.85630    0.56654  )
#         3  H       1.0078   tau(    3) = (    0.56692    0.56600    0.56654  )
#
#      Computing dynamical matrix for
#                     q = (   0.0000000   0.0000000   0.0000000 )
#
#       2 Sym.Ops. (with q -> -q+G )
#
#                                     s                        frac. trans.
#
#       isym =  1     identity
#
#  cryst.   s( 1) = (     1          0          0      )
#                   (     0          1          0      )
#                   (     0          0          1      )
#
#  cart.    s( 1) = (  1.0000000  0.0000000  0.0000000 )
#                   (  0.0000000  1.0000000  0.0000000 )
#                   (  0.0000000  0.0000000  1.0000000 )
#
#
#      This transformation sends q -> -q+G
#
#       isym =  2     identity
#
#  cryst.   s( 2) = (     1          0          0      )
#                   (     0          1          0      )
#                   (     0          0          1      )
#
#  cart.    s( 2) = (  1.0000000  0.0000000  0.0000000 )
#                   (  0.0000000  1.0000000  0.0000000 )
#                   (  0.0000000  0.0000000  1.0000000 )
#
#
#      G cutoff =  607.9271  (  62669 G-vectors)     FFT grid: ( 50, 50, 50)
#      G cutoff =  303.9636  (  22119 G-vectors)  smooth grid: ( 36, 36, 36)
#      number of k points=     1
#                        cart. coord. in units 2pi/alat
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   2.0000000
#
#                        cryst. coord.
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   2.0000000
#
#      PseudoPot. # 1 for H  read from file:
#      /content/q-e/pseudopotentials/H.UPF
#      MD5 check sum: fbb168fef676c0aaadbafd73f5b1efa8
#      Pseudo is Projector augmented-wave, Zval =  1.0
#      Generated using "atomic" code by A. Dal Corso  v.5.0.2 svn rev. 9415
#      Shape of augmentation charge: PSQ
#      Using radial grid of  929 points,  2 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#      Q(r) pseudized with 0 coefficients
#
#
#      PseudoPot. # 2 for O  read from file:
#      /content/q-e/pseudopotentials/O.UPF
#      MD5 check sum: 833c495a5d0f9b75bf046115549bffff
#      Pseudo is Projector augmented-wave + core cor, Zval =  6.0
#      Generated using &quot;atomic&quot; code by A. Dal Corso  v.6.3
#      Shape of augmentation charge: BESSEL
#      Using radial grid of 1095 points,  4 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#                 l(4) =   1
#      Q(r) pseudized with 0 coefficients
#
#
#      point group C_1 (1)
#      there are  1 classes
#      the character table:
#
#        E
# A      1.00
#
#      the symmetry operations in each class and the name of the first element:
#
#      E        1
#
#
#
#      Electric field:
#      Dielectric constant
#      Born effective charges in two ways
#
#
#      Atomic displacements:
#      There are    9 irreducible representations
#
#      Representation     1      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   1
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     2      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   2
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     3      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   3
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     4      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   4
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     5      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   5
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     6      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   6
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     7      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   7
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     8      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   8
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#                      (   0.00000   0.00000   )
#
#      Representation     9      1 modes -  To be done
#      Irreps are as follows:
#
#                      mode #   9
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   0.00000   0.00000   )
#                      (   1.00000   0.00000   )
#
#
#
#      Alpha used in Ewald sum =   2.5000
#
#      negative rho (up, down):  1.885E-04 0.000E+00
#      PHONON       :      2.82s CPU      3.00s WALL
#
#
#      Electric Fields Calculation
#
#       iter #   1 total cpu time :     4.5 secs   av.it.:   5.7
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  2.131E-07
#
#       iter #   2 total cpu time :     5.9 secs   av.it.:   8.3
#       thresh= 4.616E-05 alpha_mix =  0.400 |ddv_scf|^2 =  6.860E-08
#
#       iter #   3 total cpu time :     7.3 secs   av.it.:   9.0
#       thresh= 2.619E-05 alpha_mix =  0.400 |ddv_scf|^2 =  2.685E-09
#
#       iter #   4 total cpu time :     8.7 secs   av.it.:   8.7
#       thresh= 5.181E-06 alpha_mix =  0.400 |ddv_scf|^2 =  1.534E-10
#
#       iter #   5 total cpu time :    10.8 secs   av.it.:  10.0
#       thresh= 1.238E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.085E-12
#
#       iter #   6 total cpu time :    12.6 secs   av.it.:   9.3
#       thresh= 1.444E-07 alpha_mix =  0.400 |ddv_scf|^2 =  1.737E-13
#
#       iter #   7 total cpu time :    14.0 secs   av.it.:   9.3
#       thresh= 4.168E-08 alpha_mix =  0.400 |ddv_scf|^2 =  2.490E-14
#
#       iter #   8 total cpu time :    15.4 secs   av.it.:   9.3
#       thresh= 1.578E-08 alpha_mix =  0.400 |ddv_scf|^2 =  1.667E-15
#
#       iter #   9 total cpu time :    16.7 secs   av.it.:   9.0
#       thresh= 4.083E-09 alpha_mix =  0.400 |ddv_scf|^2 =  9.891E-17
#
#      End of electric fields calculation
#
#           Dielectric constant in cartesian axis
#
#           (       1.156626915      -0.000002989       0.000002912 )
#           (      -0.000002989       1.134320717      -0.000000938 )
#           (       0.000002912      -0.000000939       1.144502855 )
#
#           Effective charges (d Force / dE) in cartesian axis without acoustic sum rule applied (asr)
#
#            atom    1  O     Mean Z*:       -0.05974
#       Ex  (       -0.26771        0.00021       -0.00019 )
#       Ey  (        0.00004       -0.00992       -0.00005 )
#       Ez  (        0.00005       -0.00009        0.09842 )
#            atom    2  H     Mean Z*:        0.26222
#       Ex  (        0.34881       -0.00002       -0.00003 )
#       Ey  (       -0.00002        0.25936        0.06254 )
#       Ez  (        0.00000        0.10419        0.17850 )
#            atom    3  H     Mean Z*:        0.26222
#       Ex  (        0.34879       -0.00000       -0.00005 )
#       Ey  (        0.00001        0.25935       -0.06254 )
#       Ez  (       -0.00001       -0.10419        0.17851 )
#
#           Effective charges Sum: Mean:        0.46470
#               0.42988        0.00003        0.00004
#               0.00019        0.50879       -0.00009
#              -0.00026       -0.00005        0.45542
#
#           Effective charges (d Force / dE) in cartesian axis with asr applied:
#            atom    1  O     Mean Z*:       -0.21464
#       E*x (       -0.41101        0.00015       -0.00010 )
#       E*y (        0.00003       -0.17952       -0.00003 )
#       E*z (        0.00004       -0.00006       -0.05339 )
#            atom    2  H     Mean Z*:        0.10732
#       E*x (        0.20551       -0.00008        0.00006 )
#       E*y (       -0.00003        0.08977        0.06256 )
#       E*z (       -0.00001        0.10422        0.02669 )
#            atom    3  H     Mean Z*:        0.10732
#       E*x (        0.20550       -0.00007        0.00004 )
#       E*y (       -0.00000        0.08975       -0.06252 )
#       E*z (       -0.00002       -0.10416        0.02670 )
#
#
#      Representation #   1 mode #   1
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    18.4 secs   av.it.:   6.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  1.928E-06
#
#       iter #   2 total cpu time :    19.0 secs   av.it.:   9.0
#       thresh= 1.389E-04 alpha_mix =  0.400 |ddv_scf|^2 =  4.373E-07
#
#       iter #   3 total cpu time :    19.5 secs   av.it.:   9.0
#       thresh= 6.613E-05 alpha_mix =  0.400 |ddv_scf|^2 =  3.904E-08
#
#       iter #   4 total cpu time :    20.0 secs   av.it.:   8.0
#       thresh= 1.976E-05 alpha_mix =  0.400 |ddv_scf|^2 =  2.241E-11
#
#       iter #   5 total cpu time :    20.5 secs   av.it.:   8.0
#       thresh= 4.734E-07 alpha_mix =  0.400 |ddv_scf|^2 =  6.325E-12
#
#       iter #   6 total cpu time :    21.0 secs   av.it.:   9.0
#       thresh= 2.515E-07 alpha_mix =  0.400 |ddv_scf|^2 =  2.779E-13
#
#       iter #   7 total cpu time :    21.5 secs   av.it.:   8.0
#       thresh= 5.271E-08 alpha_mix =  0.400 |ddv_scf|^2 =  6.445E-16
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   2 mode #   2
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    22.1 secs   av.it.:   6.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  3.217E-06
#
#       iter #   2 total cpu time :    22.9 secs   av.it.:   8.0
#       thresh= 1.794E-04 alpha_mix =  0.400 |ddv_scf|^2 =  5.731E-07
#
#       iter #   3 total cpu time :    23.6 secs   av.it.:   9.0
#       thresh= 7.571E-05 alpha_mix =  0.400 |ddv_scf|^2 =  6.681E-08
#
#       iter #   4 total cpu time :    24.4 secs   av.it.:   8.0
#       thresh= 2.585E-05 alpha_mix =  0.400 |ddv_scf|^2 =  2.025E-10
#
#       iter #   5 total cpu time :    25.2 secs   av.it.:   8.0
#       thresh= 1.423E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.384E-11
#
#       iter #   6 total cpu time :    25.7 secs   av.it.:   9.0
#       thresh= 4.883E-07 alpha_mix =  0.400 |ddv_scf|^2 =  3.684E-13
#
#       iter #   7 total cpu time :    26.2 secs   av.it.:   8.0
#       thresh= 6.070E-08 alpha_mix =  0.400 |ddv_scf|^2 =  1.579E-15
#
#       iter #   8 total cpu time :    26.7 secs   av.it.:   8.0
#       thresh= 3.973E-09 alpha_mix =  0.400 |ddv_scf|^2 =  4.700E-16
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   3 mode #   3
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    27.3 secs   av.it.:   7.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  2.462E-06
#
#       iter #   2 total cpu time :    27.8 secs   av.it.:   9.0
#       thresh= 1.569E-04 alpha_mix =  0.400 |ddv_scf|^2 =  5.262E-07
#
#       iter #   3 total cpu time :    28.3 secs   av.it.:   9.0
#       thresh= 7.254E-05 alpha_mix =  0.400 |ddv_scf|^2 =  6.865E-08
#
#       iter #   4 total cpu time :    28.8 secs   av.it.:   9.0
#       thresh= 2.620E-05 alpha_mix =  0.400 |ddv_scf|^2 =  1.264E-08
#
#       iter #   5 total cpu time :    29.3 secs   av.it.:   9.0
#       thresh= 1.124E-05 alpha_mix =  0.400 |ddv_scf|^2 =  3.156E-11
#
#       iter #   6 total cpu time :    29.8 secs   av.it.:   9.0
#       thresh= 5.617E-07 alpha_mix =  0.400 |ddv_scf|^2 =  2.758E-12
#
#       iter #   7 total cpu time :    30.3 secs   av.it.:   9.0
#       thresh= 1.661E-07 alpha_mix =  0.400 |ddv_scf|^2 =  3.423E-14
#
#       iter #   8 total cpu time :    30.8 secs   av.it.:   9.0
#       thresh= 1.850E-08 alpha_mix =  0.400 |ddv_scf|^2 =  1.514E-15
#
#       iter #   9 total cpu time :    31.3 secs   av.it.:   9.0
#       thresh= 3.892E-09 alpha_mix =  0.400 |ddv_scf|^2 =  6.836E-17
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   4 mode #   4
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    31.9 secs   av.it.:   5.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  3.824E-08
#
#       iter #   2 total cpu time :    32.4 secs   av.it.:   9.0
#       thresh= 1.956E-05 alpha_mix =  0.400 |ddv_scf|^2 =  1.283E-08
#
#       iter #   3 total cpu time :    32.9 secs   av.it.:   8.0
#       thresh= 1.133E-05 alpha_mix =  0.400 |ddv_scf|^2 =  5.011E-10
#
#       iter #   4 total cpu time :    33.3 secs   av.it.:   8.0
#       thresh= 2.239E-06 alpha_mix =  0.400 |ddv_scf|^2 =  5.818E-11
#
#       iter #   5 total cpu time :    33.9 secs   av.it.:   9.0
#       thresh= 7.628E-07 alpha_mix =  0.400 |ddv_scf|^2 =  1.896E-12
#
#       iter #   6 total cpu time :    34.3 secs   av.it.:   9.0
#       thresh= 1.377E-07 alpha_mix =  0.400 |ddv_scf|^2 =  9.060E-15
#
#       iter #   7 total cpu time :    34.8 secs   av.it.:   8.0
#       thresh= 9.519E-09 alpha_mix =  0.400 |ddv_scf|^2 =  2.274E-15
#
#       iter #   8 total cpu time :    35.3 secs   av.it.:   9.0
#       thresh= 4.769E-09 alpha_mix =  0.400 |ddv_scf|^2 =  3.052E-18
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   5 mode #   5
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    36.2 secs   av.it.:   5.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  6.600E-08
#
#       iter #   2 total cpu time :    36.9 secs   av.it.:  10.0
#       thresh= 2.569E-05 alpha_mix =  0.400 |ddv_scf|^2 =  1.073E-08
#
#       iter #   3 total cpu time :    37.7 secs   av.it.:  10.0
#       thresh= 1.036E-05 alpha_mix =  0.400 |ddv_scf|^2 =  3.083E-09
#
#       iter #   4 total cpu time :    38.5 secs   av.it.:  10.0
#       thresh= 5.552E-06 alpha_mix =  0.400 |ddv_scf|^2 =  1.729E-10
#
#       iter #   5 total cpu time :    39.1 secs   av.it.:   9.0
#       thresh= 1.315E-06 alpha_mix =  0.400 |ddv_scf|^2 =  3.628E-12
#
#       iter #   6 total cpu time :    39.6 secs   av.it.:   9.0
#       thresh= 1.905E-07 alpha_mix =  0.400 |ddv_scf|^2 =  5.802E-13
#
#       iter #   7 total cpu time :    40.1 secs   av.it.:  10.0
#       thresh= 7.617E-08 alpha_mix =  0.400 |ddv_scf|^2 =  3.055E-15
#
#       iter #   8 total cpu time :    40.6 secs   av.it.:  10.0
#       thresh= 5.528E-09 alpha_mix =  0.400 |ddv_scf|^2 =  8.825E-16
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   6 mode #   6
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    41.2 secs   av.it.:   5.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  5.837E-08
#
#       iter #   2 total cpu time :    41.7 secs   av.it.:  10.0
#       thresh= 2.416E-05 alpha_mix =  0.400 |ddv_scf|^2 =  7.595E-09
#
#       iter #   3 total cpu time :    42.2 secs   av.it.:  10.0
#       thresh= 8.715E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.697E-09
#
#       iter #   4 total cpu time :    42.7 secs   av.it.:  10.0
#       thresh= 5.193E-06 alpha_mix =  0.400 |ddv_scf|^2 =  4.805E-11
#
#       iter #   5 total cpu time :    43.2 secs   av.it.:  10.0
#       thresh= 6.932E-07 alpha_mix =  0.400 |ddv_scf|^2 =  3.980E-12
#
#       iter #   6 total cpu time :    43.7 secs   av.it.:   9.0
#       thresh= 1.995E-07 alpha_mix =  0.400 |ddv_scf|^2 =  3.685E-13
#
#       iter #   7 total cpu time :    44.2 secs   av.it.:  10.0
#       thresh= 6.071E-08 alpha_mix =  0.400 |ddv_scf|^2 =  5.393E-15
#
#       iter #   8 total cpu time :    44.7 secs   av.it.:  10.0
#       thresh= 7.344E-09 alpha_mix =  0.400 |ddv_scf|^2 =  5.348E-16
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   7 mode #   7
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    45.2 secs   av.it.:   5.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  2.642E-08
#
#       iter #   2 total cpu time :    45.7 secs   av.it.:   9.0
#       thresh= 1.626E-05 alpha_mix =  0.400 |ddv_scf|^2 =  8.649E-09
#
#       iter #   3 total cpu time :    46.2 secs   av.it.:   8.0
#       thresh= 9.300E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.161E-10
#
#       iter #   4 total cpu time :    46.7 secs   av.it.:   9.0
#       thresh= 1.470E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.763E-11
#
#       iter #   5 total cpu time :    47.2 secs   av.it.:   9.0
#       thresh= 5.256E-07 alpha_mix =  0.400 |ddv_scf|^2 =  9.750E-13
#
#       iter #   6 total cpu time :    47.7 secs   av.it.:   9.0
#       thresh= 9.874E-08 alpha_mix =  0.400 |ddv_scf|^2 =  5.740E-15
#
#       iter #   7 total cpu time :    48.2 secs   av.it.:   8.0
#       thresh= 7.576E-09 alpha_mix =  0.400 |ddv_scf|^2 =  1.168E-15
#
#       iter #   8 total cpu time :    48.7 secs   av.it.:   8.0
#       thresh= 3.418E-09 alpha_mix =  0.400 |ddv_scf|^2 =  2.809E-18
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   8 mode #   8
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    49.5 secs   av.it.:   5.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  6.589E-08
#
#       iter #   2 total cpu time :    50.3 secs   av.it.:  10.0
#       thresh= 2.567E-05 alpha_mix =  0.400 |ddv_scf|^2 =  9.360E-09
#
#       iter #   3 total cpu time :    51.0 secs   av.it.:  10.0
#       thresh= 9.674E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.843E-09
#
#       iter #   4 total cpu time :    51.8 secs   av.it.:  10.0
#       thresh= 5.332E-06 alpha_mix =  0.400 |ddv_scf|^2 =  1.016E-10
#
#       iter #   5 total cpu time :    52.5 secs   av.it.:  10.0
#       thresh= 1.008E-06 alpha_mix =  0.400 |ddv_scf|^2 =  2.540E-12
#
#       iter #   6 total cpu time :    53.0 secs   av.it.:   9.0
#       thresh= 1.594E-07 alpha_mix =  0.400 |ddv_scf|^2 =  4.266E-13
#
#       iter #   7 total cpu time :    53.5 secs   av.it.:   9.0
#       thresh= 6.531E-08 alpha_mix =  0.400 |ddv_scf|^2 =  1.533E-15
#
#       iter #   8 total cpu time :    54.0 secs   av.it.:  10.0
#       thresh= 3.915E-09 alpha_mix =  0.400 |ddv_scf|^2 =  4.445E-16
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#
#      Representation #   9 mode #   9
#
#      Self-consistent Calculation
#
#       iter #   1 total cpu time :    54.6 secs   av.it.:   5.0
#       thresh= 1.000E-02 alpha_mix =  0.400 |ddv_scf|^2 =  6.796E-08
#
#       iter #   2 total cpu time :    55.1 secs   av.it.:   9.0
#       thresh= 2.607E-05 alpha_mix =  0.400 |ddv_scf|^2 =  1.039E-08
#
#       iter #   3 total cpu time :    55.6 secs   av.it.:  10.0
#       thresh= 1.019E-05 alpha_mix =  0.400 |ddv_scf|^2 =  3.551E-09
#
#       iter #   4 total cpu time :    56.1 secs   av.it.:  10.0
#       thresh= 5.959E-06 alpha_mix =  0.400 |ddv_scf|^2 =  4.231E-11
#
#       iter #   5 total cpu time :    56.6 secs   av.it.:  10.0
#       thresh= 6.504E-07 alpha_mix =  0.400 |ddv_scf|^2 =  4.616E-12
#
#       iter #   6 total cpu time :    57.1 secs   av.it.:   9.0
#       thresh= 2.149E-07 alpha_mix =  0.400 |ddv_scf|^2 =  3.484E-13
#
#       iter #   7 total cpu time :    57.6 secs   av.it.:   9.0
#       thresh= 5.903E-08 alpha_mix =  0.400 |ddv_scf|^2 =  5.455E-15
#
#       iter #   8 total cpu time :    58.1 secs   av.it.:  10.0
#       thresh= 7.386E-09 alpha_mix =  0.400 |ddv_scf|^2 =  3.471E-16
#
#      End of self-consistent calculation
#
#      Convergence has been achieved
#
#      Number of q in the star =    1
#      List of q in the star:
#           1   0.000000000   0.000000000   0.000000000
#
#           Dielectric constant in cartesian axis
#
#           (       1.156626915      -0.000002989       0.000002912 )
#           (      -0.000002989       1.134320717      -0.000000938 )
#           (       0.000002912      -0.000000939       1.144502855 )
#
#           Effective charges (d Force / dE) in cartesian axis without acoustic sum rule applied (asr)
#
#            atom    1  O     Mean Z*:       -0.05974
#       Ex  (       -0.26771        0.00021       -0.00019 )
#       Ey  (        0.00004       -0.00992       -0.00005 )
#       Ez  (        0.00005       -0.00009        0.09842 )
#            atom    2  H     Mean Z*:        0.26222
#       Ex  (        0.34881       -0.00002       -0.00003 )
#       Ey  (       -0.00002        0.25936        0.06254 )
#       Ez  (        0.00000        0.10419        0.17850 )
#            atom    3  H     Mean Z*:        0.26222
#       Ex  (        0.34879       -0.00000       -0.00005 )
#       Ey  (        0.00001        0.25935       -0.06254 )
#       Ez  (       -0.00001       -0.10419        0.17851 )
#
#           Effective charges Sum: Mean:        0.46470
#               0.42988        0.00003        0.00004
#               0.00019        0.50879       -0.00009
#              -0.00026       -0.00005        0.45542
#
#           Effective charges (d Force / dE) in cartesian axis with asr applied:
#            atom    1  O     Mean Z*:       -0.21464
#       E*x (       -0.41101        0.00015       -0.00010 )
#       E*y (        0.00003       -0.17952       -0.00003 )
#       E*z (        0.00004       -0.00006       -0.05339 )
#            atom    2  H     Mean Z*:        0.10732
#       E*x (        0.20551       -0.00008        0.00006 )
#       E*y (       -0.00003        0.08977        0.06256 )
#       E*z (       -0.00001        0.10422        0.02669 )
#            atom    3  H     Mean Z*:        0.10732
#       E*x (        0.20550       -0.00007        0.00004 )
#       E*y (       -0.00000        0.08975       -0.06252 )
#       E*z (       -0.00002       -0.10416        0.02670 )
#
#           Effective charges (d P / du) in cartesian axis
#
#            atom      1O
#       Px  (       -0.26787        0.00021       -0.00019 )
#       Py  (        0.00004       -0.00991       -0.00005 )
#       Pz  (        0.00005       -0.00009        0.09821 )
#            atom      2H
#       Px  (        0.34881       -0.00002       -0.00003 )
#       Py  (       -0.00002        0.25935        0.06257 )
#       Pz  (        0.00000        0.10416        0.17847 )
#            atom      3H
#       Px  (        0.34879       -0.00000       -0.00005 )
#       Py  (        0.00001        0.25934       -0.06255 )
#       Pz  (       -0.00001       -0.10416        0.17852 )
#
#      Diagonalizing the dynamical matrix
#
#      q = (    0.000000000   0.000000000   0.000000000 )
#
#  **************************************************************************
#      freq (    1) =      -7.985112 [THz] =    -266.354653 [cm-1]
#      freq (    2) =      -6.740030 [THz] =    -224.823191 [cm-1]
#      freq (    3) =      -5.513655 [THz] =    -183.915737 [cm-1]
#      freq (    4) =      18.082410 [THz] =     603.164279 [cm-1]
#      freq (    5) =      18.286517 [THz] =     609.972546 [cm-1]
#      freq (    6) =      18.985412 [THz] =     633.285173 [cm-1]
#      freq (    7) =      47.505193 [THz] =    1584.602671 [cm-1]
#      freq (    8) =     109.289697 [THz] =    3645.511879 [cm-1]
#      freq (    9) =     112.278727 [THz] =    3745.215212 [cm-1]
#  **************************************************************************
#
#      Mode symmetry, C_1 (1)     point group:
#
#      freq (   1-   1) =       -266.4  [cm-1]   --> A               I+R
#      freq (   2-   2) =       -224.8  [cm-1]   --> A               I+R
#      freq (   3-   3) =       -183.9  [cm-1]   --> A               I+R
#      freq (   4-   4) =        603.2  [cm-1]   --> A               I+R
#      freq (   5-   5) =        610.0  [cm-1]   --> A               I+R
#      freq (   6-   6) =        633.3  [cm-1]   --> A               I+R
#      freq (   7-   7) =       1584.6  [cm-1]   --> A               I+R
#      freq (   8-   8) =       3645.5  [cm-1]   --> A               I+R
#      freq (   9-   9) =       3745.2  [cm-1]   --> A               I+R
#
#      PHONON       :     55.87s CPU     58.15s WALL
#
#      INITIALIZATION:
#      phq_setup    :      0.37s CPU      0.41s WALL (       1 calls)
#      phq_init     :      1.70s CPU      1.76s WALL (       1 calls)
#
#      phq_init     :      1.70s CPU      1.76s WALL (       1 calls)
#      set_drhoc    :      0.00s CPU      0.00s WALL (       3 calls)
#      init_vloc    :      0.04s CPU      0.04s WALL (       1 calls)
#      init_us_1    :      0.11s CPU      0.11s WALL (       1 calls)
#      init_us_2    :      0.08s CPU      0.09s WALL (     126 calls)
#      newd         :      0.05s CPU      0.08s WALL (       1 calls)
#      dvanqq       :      0.57s CPU      0.58s WALL (       1 calls)
#      drho         :      0.91s CPU      0.95s WALL (       1 calls)
#      drhous       :      0.20s CPU      0.21s WALL (       1 calls)
#      nldyntot     :      0.00s CPU      0.01s WALL (       1 calls)
#      cmpt_qdipol  :      0.00s CPU      0.00s WALL (       1 calls)
#
#      DIELECTRIC CONSTANT AND EFFECTIVE CHARGES:
#      solve_e      :     13.03s CPU     13.71s WALL (       1 calls)
#      dielec       :      0.00s CPU      0.00s WALL (       1 calls)
#      zstar_eu     :      1.21s CPU      1.24s WALL (       1 calls)
#
#      DYNAMICAL MATRIX:
#      dynmat0      :      0.21s CPU      0.22s WALL (       1 calls)
#      dynmat_us    :      0.09s CPU      0.09s WALL (       1 calls)
#      addusdynmat  :      0.00s CPU      0.00s WALL (       1 calls)
#      d2ionq       :      0.05s CPU      0.05s WALL (       1 calls)
#      dynmatcc     :      0.07s CPU      0.08s WALL (       1 calls)
#      phqscf       :     38.80s CPU     40.19s WALL (       1 calls)
#      dynmatrix    :      0.00s CPU      0.00s WALL (       1 calls)
#
#      phqscf       :     38.80s CPU     40.19s WALL (       1 calls)
#      solve_linter :     38.64s CPU     39.98s WALL (       9 calls)
#      sth_kernel   :      5.34s CPU      5.45s WALL (      81 calls)
#      h_prec       :      0.01s CPU      0.01s WALL (      84 calls)
#      apply_dpot_b :      0.34s CPU      0.36s WALL (      87 calls)
#      ortho        :      0.04s CPU      0.04s WALL (     102 calls)
#      cgsolve      :      4.70s CPU      4.78s WALL (     102 calls)
#      incdrhoscf   :      0.42s CPU      0.43s WALL (     102 calls)
#                                         0.00s GPU  (     102 calls)
#      addusddens   :      6.22s CPU      6.30s WALL (      81 calls)
#      dv_of_drho   :      4.24s CPU      4.28s WALL (     102 calls)
#      mix_pot      :      0.41s CPU      1.32s WALL (      81 calls)
#      drhodv       :      0.10s CPU      0.10s WALL (       9 calls)
#      add_zstar_ue :      0.01s CPU      0.01s WALL (       9 calls)
#      add_zstar_us :      0.05s CPU      0.07s WALL (       9 calls)
#      symdvscf     :     52.59s CPU     54.69s WALL (       1 calls)
#      newdq        :      7.16s CPU      7.24s WALL (      81 calls)
#      adddvscf     :      0.01s CPU      0.01s WALL (      87 calls)
#      com_dvloc    :      0.10s CPU      0.10s WALL (     108 calls)
#                                         0.00s GPU  (     108 calls)
#      addcore      :      0.43s CPU      0.44s WALL (     189 calls)
#                                         0.00s GPU  (     189 calls)
#      drhodvus     :      0.01s CPU      0.06s WALL (       9 calls)
#
#      dvqpsi_us    :      0.08s CPU      0.09s WALL (      18 calls)
#                                         0.00s GPU  (      18 calls)
#      dvqpsi_us_on :      0.00s CPU      0.00s WALL (      18 calls)
#
#      add_vuspsi   :      0.10s CPU      0.10s WALL (    1192 calls)
#      addusdbec    :      0.01s CPU      0.01s WALL (     111 calls)
#
#      drhodvus     :      0.01s CPU      0.06s WALL (       9 calls)
#
#       General routines
#      calbec       :      0.24s CPU      0.25s WALL (    3081 calls)
#      fft          :      3.92s CPU      3.95s WALL (    1944 calls)
#      ffts         :      0.39s CPU      0.40s WALL (     319 calls)
#      fftw         :      3.72s CPU      3.79s WALL (    9300 calls)
#      davcio       :      0.11s CPU      0.96s WALL (    1320 calls)
#      write_rec    :      0.03s CPU      0.37s WALL (      90 calls)
#
#       Additional routines
#      ch_psi       :      4.56s CPU      4.64s WALL (    1192 calls)
#      last         :      0.35s CPU      0.36s WALL (    1192 calls)
#      Hesh         :      0.03s CPU      0.03s WALL (    1192 calls)
#      ch_psi_all_k :      0.32s CPU      0.32s WALL (    1192 calls)
#                                         0.00s GPU  (    1192 calls)
#      ch_psi_calbe :      0.08s CPU      0.08s WALL (    1192 calls)
#                                         0.00s GPU  (    1192 calls)
#      h_psi_bgrp   :      4.06s CPU      4.12s WALL (    1192 calls)
#      h_psi        :      4.05s CPU      4.12s WALL (    1192 calls)
#      h_psi:pot    :      4.03s CPU      4.10s WALL (    1192 calls)
#      h_psi:calbec :      0.11s CPU      0.11s WALL (    1192 calls)
#      s_psi_bgrp   :      0.23s CPU      0.24s WALL (    2489 calls)
#      s_psi        :      0.20s CPU      0.20s WALL (    2489 calls)
#
#
#      PHONON       :     55.87s CPU     58.15s WALL
#
#
#    This run was terminated on:   9:40:13  14Dec2024
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=

# %% [markdown]
# Analyze the results.

# %%
from ase.io import espresso

with open('h2o.ph.out', 'r') as handle:
    ph_h2o_results = espresso.read_espresso_ph(handle)

print("The vibronic frequencies are:")

thz_to_invcm = 33.3564095198152 # convert THz to inverse cm
ph_h2o_results[1]['freqs'] * thz_to_invcm
# Out:
# The vibronic frequencies are:
# array([-266.35466593, -224.82320086, -183.91573413,  603.16427307,
#         609.97254974,  633.28517757, 1584.60267203, 3645.51188943,
#        3745.21519818])

# %%
print("The effective charges are:")
ph_h2o_results[1]['borneffcharge']
# Out:
# The effective charges are:
# [array([[-4.1101e-01,  1.5000e-04, -1.0000e-04],
#         [ 3.0000e-05, -1.7952e-01, -3.0000e-05],
#         [ 4.0000e-05, -6.0000e-05, -5.3390e-02]]),
#  array([[ 2.0551e-01, -8.0000e-05,  6.0000e-05],
#         [-3.0000e-05,  8.9770e-02,  6.2560e-02],
#         [-1.0000e-05,  1.0422e-01,  2.6690e-02]]),
#  array([[ 2.0550e-01, -7.0000e-05,  4.0000e-05],
#         [-0.0000e+00,  8.9750e-02, -6.2520e-02],
#         [-2.0000e-05, -1.0416e-01,  2.6700e-02]])]

# %%
ph_h2o_results[1]['borneffcharge'][0].trace(), ph_h2o_results[1]['borneffcharge'][1].trace()
# Out:
# (-0.64392, 0.32197)

# %% [markdown]
# ### Step 4: calculate vibrational intensities

# %%
dynmat_inputs = """
&INPUT
  fildyn='matdyn1',
  asr='zero-dim',
  filout='h2o.dynmat.out'
/
"""

with open('h2o.dynmat.in', 'w+') as handle:
    handle.write(dynmat_inputs)

! /content/q-e/bin/dynmat.x -in h2o.dynmat.in > h2o.dynmat.out # run the dynmat.x executable

! cat h2o.dynmat.out
# Out:
#      Program DYNMAT v.7.4 starts on 14Dec2024 at 11:17:42
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#          "P. Giannozzi et al., J. Chem. Phys. 152 154105 (2020);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Serial version
#      8788 MiB available memory on the printing compute node when the environment starts
#
#
#      Reading Dynamical Matrix from file matdyn1
#      ...Force constants read
#      ...epsilon and Z* read
#      Acoustic Sum Rule: || Z*(ASR) - Z*(orig)|| =    7.069265E-01
#      Acoustic Sum Rule: ||dyn(ASR) - dyn(orig)||=    5.581188E-01
#      A direction for q was not specified:TO-LO splitting will be absent
#
#      Polarizability (A^3 units)
#      multiply by 0.953850 for Clausius-Mossotti correction
#          1.846970   -0.000035    0.000034
#         -0.000035    1.583932   -0.000011
#          0.000034   -0.000011    1.704001
#
#      IR activities are in (D/A)^2/amu units
#
# # mode   [cm-1]    [THz]      IR
#     1     -0.00   -0.0001    0.0000
#     2     -0.00   -0.0000    0.0000
#     3     -0.00   -0.0000    0.0000
#     4      0.00    0.0000    0.0000
#     5      0.00    0.0000    0.0000
#     6      0.00    0.0000    0.0000
#     7   1740.47   52.1779    0.3358
#     8   3681.03  110.3545    0.1979
#     9   3864.65  115.8594    0.2958
#
#      DYNMAT       :      0.01s CPU      0.01s WALL
#
#
#    This run was terminated on:  11:17:42  14Dec2024
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=
# 7267   0.000000   )
#      freq (    7) =      52.177896 [THz] =    1740.467271 [cm-1]
#  ( -0.000001   0.000000     0.000003   0.000000    -0.069137   0.000000   )
#  (  0.000006   0.000000     0.443233   0.000000     0.548776   0.000000   )
#  (  0.000006   0.000000    -0.443274   0.000000     0.548742   0.000000   )
#      freq (    8) =     110.354544 [THz] =    3681.031357 [cm-1]
#  ( -0.000001   0.000000     0.000016   0.000000    -0.051858   0.000000   )
#  (  0.000005   0.000000    -0.573913   0.000000     0.411712   0.000000   )
#  (  0.000005   0.000000     0.573661   0.000000     0.411511   0.000000   )
#      freq (    9) =     115.859376 [THz] =    3864.652783 [cm-1]
#  (  0.000000   0.000000    -0.069928   0.000000    -0.000015   0.000000   )
#  ( -0.000005   0.000000     0.554923   0.000000    -0.435180   0.000000   )
#  (  0.000005   0.000000     0.555159   0.000000     0.435416   0.000000   )
#  **************************************************************************

# %% [markdown]
# The result should be comparable to the following:
#
# | mode | [cm-1]  |  [THz]    |   IR    |
# |------|---------|-----------|---------|
# |    1 |  -0.00  |  -0.0000  | 0.0000  |
# |    2 |  -0.00  |  -0.0000  | 0.0000  |
# |    3 |  -0.00  |  -0.0000  | 0.0000  |
# |    4 |   0.00  |   0.0000  | 0.0000  |
# |    5 |   0.00  |   0.0000  | 0.0000  |
# |    6 |   0.00  |   0.0000  | 0.0000  |
# |    7 | 1676.57 |  50.2622  | 1.1143  |
# |    8 | 3724.30 | 111.6518  | 0.0041  |
# |    9 | 3841.84 | 115.1754  | 2.2215  |

# %% [markdown]
# ![vibrationalspectra.png](https://arxiv.org/html/2312.15211v2/x4.png)
#
# Taken from _Kovács, D. V. et al, (2024) arXiv:2312.15211_
